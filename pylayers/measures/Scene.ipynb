# %%
from pylayers.gis.layout import *
from pylayers.mobility.ban.c3d import *
from pylayers.mobility.ban.body import *
import pandas as pd

# %%
# %matplotlib inline

# %%
#CORMORAN='/home/uguen/svn2/measures/CORMORAN/'
#CORMORAN='/media/niamiot/DONNEES/svn2/measures/CORMORAN/'
import os
CORMORAN = os.environ['CORMORAN']

# %%
L=Layout('MOCAP.ini')
# Out:
# problem to construct geomfile

# %%
u = ReadC3d('scene.c3d')
# Out:
# *************************
# **** Processor coding ***
# *************************
# Intel-PC

# %%
pts=u[2]

# %%
cam = pd.read_csv(CORMORAN+'POST-TREATED/camccoord.csv')/1000
cam
# Out:
#            x         y         z
# 0  -6.502166  5.440980  2.296444
# 1  -7.782349  4.998476  2.417586
# 2   8.308829  3.618505  2.698077
# 3   5.606683 -6.354179  2.500278
# 4  -8.237919 -2.332986  4.765318
# 5   5.496094  6.216919  2.433300
# 6  -8.296197  2.430073  4.794016
# 7   7.718375 -4.644268  2.584753
# 8   8.471272 -3.043746  2.683451
# 9  -8.213048 -4.034574  2.368545
# 10 -7.184667 -4.950494  2.317686
# 11  7.531661  5.279024  2.479363
# 12 -6.303086 -7.057062  2.288849
# 13 -5.441178  6.637930  2.315157
# 14  8.287799  0.059161  4.809145
#
# [15 rows x 3 columns]

# %%
B=Body('Nicolas.ini',_filemocap='serie_007.c3d',unit='mm')
# Out:
# *************************
# **** Processor coding ***
# *************************
# Intel-PC
# *************************
# **** Processor coding ***
# *************************
# Intel-PC

# %%
L.showG('s',figsize=(20,20))
a= plt.plot(-pts[:,:,1]/1000,pts[:,:,0]/1000,'.')
b= plt.plot(-cam['y'],cam['x'],'ok')
plt.axis([-13,13,-13,13])
plt.plot(-B.traj['y'],B.traj['x'],'r')

# %%
B.dev['6']
# Out:
# {'T': array([[1, 0, 0],
#         [0, 1, 0],
#         [0, 0, 1]]),
#  'comment': '1 Right chest',
#  'file': 'S17R2m.sh3',
#  'name': 'HKB',
#  'radiomarkname': 'RFChest',
#  'status': 'real',
#  'typ': 'static',
#  'uc3d': array([44])}

# %%
B.settopos(t=1,cs=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-e89a79bd038d> in <module>()
# ----> 1 B.settopos(t=1,cs=True)
#
# /home/niamiot/Documents/code/pylayers/pylayers/mobility/ban/body.py in settopos(self, traj, t, cs, treadmill, p0)
#     735             self.setccs(topos=True)
#     736             # calculate device coordinate system
# --> 737             self.setdcs(topos=True)
#     738             # calculate antenna coordinate system
#     739             self.setacs()
#
# /home/niamiot/Documents/code/pylayers/pylayers/mobility/ban/body.py in setdcs(self, topos, frameId)
#     865                         # vector tail device
#     866                         de = self._f[0,self.dev[dev]['uc3d'],:]
# --> 867                         td = pta - de[0,:,np.newaxis]
#     868                         tdl = np.sqrt(np.sum(td**2,axis=0))
#     869
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
Bernard=Body('Bernard.ini')
# Out:
# *************************
# **** Processor coding ***
# *************************
# Intel-PC

# %%
Bernard
# Out:
# My name is : Bernard
#
# I have a TCR device with id #25 on RFChest
# I have a TCR device with id #26 on RWrist
# I have a TCR device with id #48 on LWrist
# I have a TCR device with id #33 on LKnee
# I have a TCR device with id #30 on LFChest
# I have a TCR device with id #37 on LAnk
# I have a TCR device with id #36 on RAnk
# I have a TCR device with id #35 on BChest
# I have a TCR device with id #34 on RHead
# I have a TCR device with id #2 on LChest
# I am nowhere yet
#
# filename : serie_017_noDEC_Real.c3d
# nframes : 11213
# Centered : True
# Mocap Speed : 0.035 m/s

# %%
Bernard.show(frameId=500,plane='xz',color='b',widthfactor=50,offset=0)
a = plt.axis('scaled')

# %%
fig = plt.figure(figsize=(20,20))
Bernard.chronophoto(tstart=0,tend=10,tstep=2,sstep=1,fig=fig)
# Out:
# (<matplotlib.figure.Figure at 0x7fb715a6b350>,
#  <matplotlib.axes.AxesSubplot at 0x7fb715892ad0>)

# %% [markdown]
# The `dev` member is a dictionnary which contains the following (key,value) pairs.
# + file : the antenna pattern file name
# + comment : a comment string
# + name :
# + radiomarkname :
# + status : 'real' |
# + typ : 'static' |

# %%
Bernard._f.shape
# Out:
# (11213, 66, 3)

# %%
Bernard.d.shape
# Out:
# (3, 16, 11213)

# %%
Bernard._p[44]
# Out:
# 'Bernard:RFChestNode'

# %%
tra=Bernard.traj

# %%
plt.figure(figsize=(10,10))
tra.plot()
# Out:
# (<matplotlib.figure.Figure at 0x7fb718967ed0>,
#  <matplotlib.axes.AxesSubplot at 0x7fb718967cd0>)

# %%
Bernard.rdpdf()
# Out:
#                            dev_id     dev_x     dev_y     dev_z
# 1970-01-01 00:00:00            25 -0.023860  0.057557  1.261551
# 1970-01-01 00:00:00             2  0.226377  0.084954  1.026368
# 1970-01-01 00:00:00            48  0.338556  0.167366  0.919395
# 1970-01-01 00:00:00            33  0.285826  0.238016  0.404159
# 1970-01-01 00:00:00            30  0.181496  0.047490  1.262553
# 1970-01-01 00:00:00            37  0.278168  0.292254  0.059259
# 1970-01-01 00:00:00            36 -0.077351  0.339767  0.096865
# 1970-01-01 00:00:00            35  0.096172  0.341086  1.158815
# 1970-01-01 00:00:00            34 -0.040582  0.157053  1.698461
# 1970-01-01 00:00:00            26 -0.212020  0.143682  0.921901
# 1970-01-01 00:00:00.010001     25 -0.023887  0.057491  1.261520
# 1970-01-01 00:00:00.010001     30  0.181515  0.047434  1.262475
# 1970-01-01 00:00:00.010001     37  0.278168  0.292254  0.059259
# 1970-01-01 00:00:00.010001     26 -0.212020  0.143682  0.921901
# 1970-01-01 00:00:00.010001      2  0.226321  0.084853  1.026323
# 1970-01-01 00:00:00.010001     36 -0.077351  0.339767  0.096865
# 1970-01-01 00:00:00.010001     35  0.096186  0.341030  1.158737
# 1970-01-01 00:00:00.010001     33  0.285826  0.238016  0.404159
# 1970-01-01 00:00:00.010001     48  0.338556  0.167366  0.919395
# 1970-01-01 00:00:00.010001     34 -0.040931  0.156888  1.698704
# 1970-01-01 00:00:00.020002     25 -0.023885  0.057456  1.261479
# 1970-01-01 00:00:00.020002     33  0.285772  0.238003  0.404147
# 1970-01-01 00:00:00.020002     26 -0.212100  0.143749  0.921910
# 1970-01-01 00:00:00.020002     30  0.181446  0.047352  1.262436
# 1970-01-01 00:00:00.020002     35  0.096224  0.340988  1.158673
# 1970-01-01 00:00:00.020002     36 -0.077412  0.339757  0.096880
# 1970-01-01 00:00:00.020002     48  0.338579  0.167267  0.919311
# 1970-01-01 00:00:00.020002     34 -0.040475  0.156920  1.698538
# 1970-01-01 00:00:00.020002      2  0.226265  0.084811  1.026297
# 1970-01-01 00:00:00.020002     37  0.278272  0.292318  0.059297
# ...                           ...       ...       ...       ...
# 1970-01-01 00:01:52.089996     48  0.405626  0.220444  0.932086
# 1970-01-01 00:01:52.089996     36  0.040991  0.312911  0.104741
# 1970-01-01 00:01:52.089996     25  0.061564  0.039875  1.263717
# 1970-01-01 00:01:52.089996     34  0.031593  0.082298  1.682687
# 1970-01-01 00:01:52.089996      2  0.317333  0.088537  1.055099
# 1970-01-01 00:01:52.089996     37  0.284986  0.286829  0.058678
# 1970-01-01 00:01:52.089996     26 -0.123030  0.150437  0.925399
# 1970-01-01 00:01:52.089996     33  0.320638  0.235878  0.404901
# 1970-01-01 00:01:52.089996     30  0.265329  0.046491  1.261260
# 1970-01-01 00:01:52.089996     35  0.157855  0.335596  1.187595
# 1970-01-01 00:01:52.099997     36  0.041002  0.312829  0.104735
# 1970-01-01 00:01:52.099997     48  0.405378  0.220633  0.932114
# 1970-01-01 00:01:52.099997     26 -0.123127  0.150108  0.925213
# 1970-01-01 00:01:52.099997     37  0.285585  0.287407  0.059043
# 1970-01-01 00:01:52.099997     30  0.265201  0.046560  1.261174
# 1970-01-01 00:01:52.099997      2  0.317218  0.088708  1.055140
# 1970-01-01 00:01:52.099997     34  0.031183  0.081983  1.682676
# 1970-01-01 00:01:52.099997     33  0.320599  0.235858  0.404954
# 1970-01-01 00:01:52.099997     25  0.061473  0.039599  1.263603
# 1970-01-01 00:01:52.099997     35  0.157278  0.335457  1.187468
# 1970-01-01 00:01:52.109998     33  0.320558  0.235855  0.404999
# 1970-01-01 00:01:52.109998     36  0.041015  0.312758  0.104751
# 1970-01-01 00:01:52.109998     37  0.285008  0.286921  0.058773
# 1970-01-01 00:01:52.109998     30  0.265127  0.046594  1.261075
# 1970-01-01 00:01:52.109998     48  0.405160  0.220712  0.932089
# 1970-01-01 00:01:52.109998      2  0.317205  0.088810  1.055114
# 1970-01-01 00:01:52.109998     26 -0.123158  0.149757  0.924996
# 1970-01-01 00:01:52.109998     25  0.061369  0.039321  1.263432
# 1970-01-01 00:01:52.109998     35  0.156689  0.335317  1.187259
# 1970-01-01 00:01:52.109998     34  0.030789  0.081682  1.682630
#
# [112110 rows x 4 columns]

# %%
ddev = {}
tdev = []
for k in Bernard.dev:
    ddev[k] = (Bernard.dev[k]['radiomarkname'],Bernard.dev[k]['uc3d'][0])
    tdev.append(Bernard.dev[k]['uc3d'][0])
tdev = np.array(tdev)

# %%
tdev
# Out:
# array([44, 62, 54, 50, 43, 46, 58, 45, 41, 42])

# %% [markdown]
# In a first step we will take only the first marker of each group of marker as the estimate of the device position. This approach will be refined further on.

# %%
Network= Bernard._f[:,tdev,:]

# %%
D = Network[:,:,np.newaxis,:]-Network[:,np.newaxis,:,:]
V = (D[1:,:,:,:]-D[0:-1,:,:,:])/0.01
A = (V[1:,:,:,:]-V[0:-1,:,:,:])/0.01
print D.shape
# Out:
# (11213, 10, 10, 3)

# %%
D2 = np.sqrt(np.sum(D*D,axis=3))
D2 = D2.reshape(11213,100)

# %%
V2 = np.sqrt(np.sum(V*V,axis=3))
V2 = V2.reshape(11212,100)

# %%
A2 = np.sqrt(np.sum(A*A,axis=3))
A2 = A2.reshape(11211,100)

# %%
plt.figure(figsize=(20,10))
plt.imshow(D2.T[0:49],interpolation='nearest',aspect='auto')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fb7199cd170>

# %%
plt.figure(figsize=(20,10))
plt.imshow(V2.T[0:49],interpolation='nearest',aspect='auto')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fb7196e61b8>

# %%
plt.plot(A2[:,4])
plt.plot(A2[:,16]+30)
