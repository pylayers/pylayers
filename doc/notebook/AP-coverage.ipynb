# %% [markdown]
# # Coverage with a Multi Wall model

# %% [markdown]
# > Sometimes it might be useful to get a fast estimate about propagation losses in an indoor environment.
# > Ray tracing is generally more time consuming and depending on the purpose of the study, it could be relevant
# > to proceed with a simpler approach while staying site-specific. `PyLayers` provides such a tool which heavily relies on the core module `slab.py`

# %% [markdown]
# First let's import the `coverage` module

# %%
from pylayers.antprop.coverage import *
import time

# %% [markdown]
# Instantiate a coverage object.
# By defaut, `TA-Office.str` layout strucure is loaded.
#
# This information can be modified in the **coverage.ini** file in the project directory.
#
# Below is an example of how the content of the file looks like

# %%
# !cat $BASENAME/ini/coverage.ini
# Out:
# [grid]
# nx = 20
# ny = 10
# boundary = [20,0,30,20]
# full = True
#
# [layout]
# filename = TA-Office.ini ; 0 40 0 15
# ;filename = W2PTIN.ini
# ;filename = Lstruc.str
#
# [ap]
# 0 = {'name':'room1','wstd':'ieee80211b','p':(1,12,1.2),'PtdBm':0,'chan':[11]}
# 1 = {'name':'room2','wstd':'ieee80211b','p':(10,2,1.2),'PtdBm':0,'chan':[11]}
# 2 = {'name':'room3','wstd':'ieee80211b','p':(20,1,1.2),'PtdBm':0,'chan':[11]}
# 3 = {'name':'room4','wstd':'ieee80211b','p':(36.5,1.5,1.2),'PtdBm':0,'chan':[11]}
# 4 = {'name':'room5','wstd':'ieee80211b','p':(25,12,1.2),'PtdBm':0,'chan':[11]}
# [rx]
# sensitivity  = -80
# bandwidthmhz = 3
# temperaturek = 300
# noisefactordb = 13
#
# [show]
# show = True

# %%
# Create a Coverage object from coverag.ini file
C = Coverage()

# %% [markdown]
# The coverage object has a `__repr__` which summarizes the different parameters of the current coverage object

# %%
C
# Out:
# Layout file : TA-Office.ini
#
# -----list of Access Points ------
# name : room1
# p : (1, 12, 1.2)
# PtdBm : 0
# channels  : [11]   2.462 : [2.451,2.473]
# sensdBm : -94
# nant : 1
#
# name : room2
# p : (10, 2, 1.2)
# PtdBm : 0
# channels  : [11]   2.462 : [2.451,2.473]
# sensdBm : -94
# nant : 1
#
# name : room3
# p : (20, 1, 1.2)
# PtdBm : 0
# channels  : [11]   2.462 : [2.451,2.473]
# sensdBm : -94
# nant : 1
#
# name : room4
# p : (36.5, 1.5, 1.2)
# PtdBm : 0
# channels  : [11]   2.462 : [2.451,2.473]
# sensdBm : -94
# nant : 1
#
# name : room5
# p : (25, 12, 1.2)
# PtdBm : 0
# channels  : [11]   2.462 : [2.451,2.473]
# sensdBm : -94
# nant : 1
#
# -----Rx------
# rxsens (dBm) : -80
# bandwith (Mhz) : 3
# temperature (K) : 300
# noisefactor (dB) : 13
#
# --- Grid ----
# nx : 20
# ny : 10
# nlink : 1000
# full grid : True
# boundary (xmin,ymin,xmax,ymax) : [20, 0, 30, 20]

# %% [markdown]
# Then, the coverage calculation is launched by calling the `cover()` method

# %%
# evaluate coverage 
C.cover()

# %% [markdown]
# # Calculating Received Power Coverage

# %% [markdown]
# Let display the current Layout with hidding nodes.

# %%
C.L.display['nodes']=False
C.L.display['ednodes']=False
C.L.showGs()
# Out:
# (<matplotlib.figure.Figure at 0x7f94fc204b50>,
#  <matplotlib.axes.AxesSubplot at 0x916f1d0>)

# %% [markdown]
# The shadowing map coverage results can be displayed by invoquing various functions.
#
# + showLoss : display the path loss
# + showPower : display the received powercover

# %%
C.show(typ='pr')
# Out:
# (<matplotlib.figure.Figure at 0x2f9b210>,
#  <matplotlib.axes.AxesSubplot at 0x7f94fcf73a90>)

# %%
C.show(typ='loss')
# Out:
# (<matplotlib.figure.Figure at 0x7f94fd2121d0>,
#  <matplotlib.axes.AxesSubplot at 0x7f94fd13dd10>)
