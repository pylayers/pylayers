# %%
from IPython.display import Image, HTML, Latex, YouTubeVideo
import numpy as np

# %%
#YouTubeVideo('1Qa6xLpU5-M')

# %%
import pylayers.mobility.trajectory as traj
from pylayers.mobility.body.body import *
from pylayers.gis.layout import *

# %% [markdown]
# trajectories can be imported from a simulnet simulation with the `importsn` method

# %%
L=Layout('TA-Office.ini')

# %%
t=traj.importsn()

# %%
figsize(10,10)
L.showGs()
t[0].plot()
t[1].plot()
t[2].plot()
t[3].plot()
# Out:
# (<matplotlib.figure.Figure at 0x58d9310>,
#  <matplotlib.axes.AxesSubplot at 0x3fa0e10>)

# %%
bc=Body('John.ini')

# %%
bc.movie(traj=t[0])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-b21a0f5a3667> in <module>()
# ----> 1 bc.movie(traj=t[0])
#
# /home/uguen/Documents/rch/devel/pylayers/pylayers/mobility/body/body.pyc in movie(self, **kwargs)
#
# /home/uguen/Documents/rch/devel/pylayers/pylayers/mobility/body/body.pyc in geomfile(self, **kwargs)
#
# /home/uguen/Documents/rch/devel/pylayers/pylayers/util/geomutil.pyc in __init__(self, _filename, clear)
#
# /home/uguen/Documents/rch/devel/pylayers/pylayers/util/geomutil.pyc in __init__(self, _filename, clear)
#
# IOError: [Errno 2] No such file or directory: '/home/uguen/Bureau/P1/geom/000165-body.list'

# %%
tr=traj.Trajectory()
