# %%
from IPython.display import Image, HTML, Latex, YouTubeVideo
import numpy as np

# %%
#YouTubeVideo('1Qa6xLpU5-M')

# %%
import pylayers.mobility.trajectory as traj
from pylayers.mobility.body.body import *
from pylayers.gis.layout import *

# %% [markdown]
# trajectories can be generated using simulnet.

# %%
from pylayers.simul.simulnet import *
S=Simul()
# set simulation duration
S.sim_opt['duration']=10

# turn off network simulation
S.net_opt['network']=False

# run mechanical simulation
S.runsimul()
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:528: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   self._handle = tables.openFile(self._path, self._mode, **kwargs)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:1044: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   return self._handle.getNode(self.root, key)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:1044: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   return self._handle.getNode(self.root, key)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:1251: DeprecationWarning: createGroup() is pending deprecation, use create_group() instead. You may use the pt2to3 tool to update your source code.
#   group = self._handle.createGroup(path, p)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:3592: DeprecationWarning: createTable() is pending deprecation, use create_table() instead. You may use the pt2to3 tool to update your source code.
#   table = self._handle.createTable(self.group, **options)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:3032: DeprecationWarning: createIndex() is pending deprecation, use create_index() instead. You may use the pt2to3 tool to update your source code.
#   v.createIndex(**kw)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:1044: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   return self._handle.getNode(self.root, key)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:1044: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   return self._handle.getNode(self.root, key)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:1251: DeprecationWarning: createGroup() is pending deprecation, use create_group() instead. You may use the pt2to3 tool to update your source code.
#   group = self._handle.createGroup(path, p)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:3592: DeprecationWarning: createTable() is pending deprecation, use create_table() instead. You may use the pt2to3 tool to update your source code.
#   table = self._handle.createTable(self.group, **options)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:3032: DeprecationWarning: createIndex() is pending deprecation, use create_index() instead. You may use the pt2to3 tool to update your source code.
#   v.createIndex(**kw)

# %% [markdown]
# trajectories can be imported from a simulnet simulation with the `importh5` method

# %%
from pylayers.mobility.trajectory import *

# %%
str1 = eval(S.sim_opt['filename'])
str2 = S.L.filename.split('.')[0]
# the save filename is composed of simulation filename and layout filename
save_filename = str1 + '_' + str2 +'.h5'

list_traj = importh5(save_filename)
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:528: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   self._handle = tables.openFile(self._path, self._mode, **kwargs)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:1031: DeprecationWarning: walkNodes() is pending deprecation, use walk_nodes() instead. You may use the pt2to3 tool to update your source code.
#   g for g in self._handle.walkNodes()
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:1044: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   return self._handle.getNode(self.root, key)
# /usr/local/lib/python2.7/site-packages/pandas/io/pytables.py:1044: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   return self._handle.getNode(self.root, key)

# %% [markdown]
# The 2 following trajectories have been calculated with `pylayers.simul.simulnet`

# %%
c
f=plt.figure(figsize=(20,20))
f,a = S.L.showGs(fig=f)
for nodes in list_traj:
    f,a = nodes.plot(fig=f,ax=a)
# Out:
# ipdb> c
# ipdb> c
# ipdb> c
# ipdb> c
# ipdb> c
# ipdb> c
# ipdb> c
# ipdb> c
# ipdb> c
# ipdb> c

# %%
importsn()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-965e0a39153b> in <module>()
# ----> 1 importsn()
#
# /private/staff/t/ot/niamiot/Documents/Code/pylayers/pylayers/mobility/trajectory.pyc in importsn(_filename)
#     280         pt = np.vstack((x,y,z))
#     281         lt.append(Trajectory(dt['time'].values,pt=pt.T,unit='s'))
# --> 282     return(lt)
#     283
#     284 def importh5(_filename='simulnet_def_str.h5'):
#
# TypeError: __init__() got an unexpected keyword argument 'pt'
