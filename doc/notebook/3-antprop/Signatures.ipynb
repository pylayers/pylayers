# %% [markdown]
# # Ray Signatures

# %%
import time
from pylayers.gis.layout import *
from pylayers.antprop.signature import *
from pylayers.antprop.rays import *

# %%
L = Layout('defstr.ini')
try:
#    L.dumpr()
except:
    L.build()
    L.dumpw()

# %% [markdown]
# Showing the graph of rooms with 2 rooms separated by a DOOR segment

# %%
L.showG('v')
a=plt.axis('off')

# %% [markdown]
# The graph of interactions is shown below.

# %%
L.showG('i',figsize=(20,20))
a=plt.axis('off')

# %% [markdown]
# All the interactions of a given cycle are stored as meta information in nodes of `Gt`

# %%
L.Gt.node[0]['inter']
# Out:
# ['(3, 0)',
#  '(4, 0)',
#  '(7, 0)',
#  '(7, 0, 1)',
#  '(7, 1, 0)',
#  '(9, 0)',
#  '(9, 0, 1)',
#  '(9, 1, 0)',
#  '(8, 0)',
#  '(8, 0, 1)',
#  '(8, 1, 0)',
#  '(2, 0)']

# %% [markdown]
# The signature is calculated with as parameters the  Layout object and two cycle numbers.
# In example below it is 0 and 1.

# %%
Si = Signatures(L,0,1)

# %% [markdown]
# The cold start determination of the signature is done with `run1` function. The code is not in its final shape here and there is room for significant acceleration in incorporating propagation based heuristics. The mitigation of combinatorics explosion is done in setting a cutoff value which limits the exploration in the interaction graph.

# %%
Si.run4(cutoff=5)

# %% [markdown]
# An exhaustive search of signatures when no prior information is given is a combinatory hard problem.
# The number of signatures grows rapidly with the cutoff parameter.

# %% [markdown]
# The representaion method of a signature gives informations about the different signatures. Signatures are grouped by number of interactions.

# %%
L.Gt.pos
# Out:
# {0: (7.5, 0.0), 1: (2.5, -0)}

# %%
ptx = np.array(L.Gt.pos[0])+np.random.rand(2)
prx = np.array(L.Gt.pos[1])+np.random.rand(2)
print ptx
print prx
# Out:
# [ 8.44222223  0.10813772]
# [ 3.14124235  0.53389142]

# %% [markdown]
# Evaluate performances of signature and ray evaluation

# %%
tt1 = {}
tt2 = {}
tint={}
tsig={} # number of sig
tray={} # number of rays
maxcutoff=9
for cutoff in range(2,maxcutoff):
     del Si
        
     Si = Signatures(L,0,1)
     tic1=time.time()
     Si.run4(cutoff=cutoff)
     tic2=time.time()
     r2d = Si.rays(ptx,prx)   
     tic3=time.time()
     Si.num()   
     Nr = len(r2d)   
     tt1[cutoff]=tic2-tic1
     tt2[cutoff]=tic3-tic2   
     tint[cutoff]=Si.nint   
     tsig[cutoff]=Si.nsig
     tray[cutoff]=Nr
     print cutoff,tt2[cutoff]
#    L.display['ednodes']=False
#    r2d.show(L)
# Out:
# 2 0.127467155457
# 3
#  0.330342054367
# 4
#  0.733642101288
# 5
#  1.31242895126
# 6
#  1.94693613052
# 7
#  2.43563103676
# 8
#  2.63910698891

# %% [markdown]
# It appears that the increasing number of signatures obatined with the run1 algorithm do not yield necessarily a significant increase in the number of rays.

# %%
p1=semilogy(tt1.keys(),tray.values(),'ob')
p2=semilogy(tt1.keys(),tsig.values(),'or')
legend((p1[0],p2[0]),('rays','signature'),loc='best')
xlabel('cutoff')
ylabel('#')

# %%
#b1=bar(tt2.keys(),tt2.values(),color='red')
#b2=bar(tt1.keys(),tt1.values(),color='blue')
#b1=semilogx(tt2.keys(),log10(tt2.values()),color='red')
#b2=semilogx(tt1.keys(),log10(tt1.values()),color='blue')
#b3=semilogx(tt1.keys(),log10(0.1*(arange(10))**3),color='green')
b1=loglog(tt2.keys(),tt2.values(),'k.')
b2=loglog(tt1.keys(),tt1.values(),'r.')
b3=loglog(tt1.keys(),0.1*arange(maxcutoff)**3,color='green')
b4=loglog(tt1.keys(),0.001*arange(maxcutoff)**2,color='green')
b5=loglog(tt1.keys(),0.1*arange(maxcutoff)**4.4,color='cyan')
legend((b1[0],b2[0],b3[0],b4[0],b5[0]),('rays','signature',r'$O(N^3)$',r'$O(N^2)$',r'$O(N^{4.4})$'),loc='best')
xlabel('cutoff')
ylabel('time (s)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a4a54b2b55b3> in <module>()
#       6 b1=loglog(tt2.keys(),tt2.values(),'k.')
#       7 b2=loglog(tt1.keys(),tt1.values(),'r.')
# ----> 8 b3=loglog(tt1.keys(),0.1*arange(maxcutoff)**3,color='green')
#       9 b4=loglog(tt1.keys(),0.001*arange(maxcutoff)**2,color='green')
#      10 b5=loglog(tt1.keys(),0.1*arange(maxcutoff)**4.4,color='cyan')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/pyplot.pyc in loglog(*args, **kwargs)
#    2753         ax.hold(hold)
#    2754     try:
# -> 2755         ret = ax.loglog(*args, **kwargs)
#    2756         draw_if_interactive()
#    2757     finally:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/axes.pyc in loglog(self, *args, **kwargs)
#    4128         b =  self._hold
#    4129         self._hold = True # we've already processed the hold
# -> 4130         l = self.plot(*args, **kwargs)
#    4131         self._hold = b    # restore the hold
#    4132
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    3994         lines = []
#    3995
# -> 3996         for line in self._get_lines(*args, **kwargs):
#    3997             self.add_line(line)
#    3998             lines.append(line)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     328                 return
#     329             if len(remaining) <= 3:
# --> 330                 for seg in self._plot_args(remaining, kwargs):
#     331                     yield seg
#     332                 return
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     306             x = np.arange(y.shape[0], dtype=float)
#     307
# --> 308         x, y = self._xy_from_xy(x, y)
#     309
#     310         if self.command == 'plot':
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/axes.pyc in _xy_from_xy(self, x, y)
#     246         y = np.atleast_1d(y)
#     247         if x.shape[0] != y.shape[0]:
# --> 248             raise ValueError("x and y must have same first dimension")
#     249         if x.ndim > 2 or y.ndim > 2:
#     250             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %%
b1=loglog(tt2.keys(),tint.values(),color='red')
b2=loglog(tt1.keys(),tsig.values(),color='blue')
#b3=loglog(tt1.keys(),arange(maxcutoff)**3,color='green')
#b4=loglog(tt1.keys(),arange(maxcutoff)**2,color='green')
#legend((b1[0],b2[0],b3[0],b4[0]),('interactions','signatures',r'$O(N^3)$',r'$O(N^2)$'),loc='best')
legend((b1[0],b2[0]),('interactions','signatures'),loc='best')
xlabel('cutoff')
ylabel('#')

# %%
#b1=loglog(tsig.values(),tt1.values(),color='red')
b2=loglog(tint.values(),tt2.values(),color='red')
b3=loglog(tint.values(),0.0004*array(tint.values())**0.88,color='blue')
xlabel('# Interactions')

# %%
plot(tint.values(),tt2.values(),color='red')
plot(tint.values(),0.0004*array(tint.values())**0.88,color='blue')

# %% [markdown]
# The computation time in rays grows exponentially with the number of interactions.
#
# $$T_{rays}=\alpha N_i^{0.88} [s]$$

# %%
b1=loglog(tt2.keys(),tint.values(),color='red')
b2=loglog(tt2.keys(),array(tt2.keys())**5,color='blue')

# %%
for k in range(2,maxcutoff):
    r2d.show(L,i=k+1,colray='red',widthray=0.5)
    title(str(k+1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-f600ec0f8f9f> in <module>()
#       1 for k in range(2,maxcutoff):
# ----> 2     r2d.show(L,i=k+1,colray='red',widthray=0.5)
#       3     title(str(k+1))
#
# /home/uguen/Documents/rch/devel/pylayers/pylayers/antprop/rays.pyc in show(self, L, **kwargs)
#     186         for i in lgrint:
#     187             if kwargs['r']==-1:
# --> 188                 lray = range(len(self[i]['pt'][0, 0, :]))
#     189                 if self.filled :
#     190                     ax.set_title('rays index :'+ str(self[i]['rayidx']))
#
# KeyError: 9

# %%
fig,ax=r2d.show(L,i=1,figsize=(20,10),colray='red',widthray=3)
fig,ax=r2d.show(L,i=1,colray='green',widthray=2,fig=fig,ax=ax)
fig,ax=r2d.show(L,i=2,colray='blue',widthray=1,fig=fig,ax=ax)
fig,ax=r2d.show(L,i=3,colray='black',widthray=1,fig=fig,ax=ax)
fig,ax=r2d.show(L,i=4,colray='green',widthray=0.5,fig=fig,ax=ax)
fig,ax=r2d.show(L,i=5,colray='green',widthray=0.5,fig=fig,ax=ax)
fig,ax=r2d.show(L,i=6,colray='green',widthray=0.5,fig=fig,ax=ax)
fig,ax=r2d.show(L,i=7,colray='green',widthray=0.5,fig=fig,ax=ax)
#fig,ax=r2d.show(L,i=8,colray='green',widthray=0.5,fig=fig,ax=ax)
#fig,ax=r2d.show(L,i=9,colray='green',widthray=0.5,fig=fig,ax=ax)

# %%
from IPython.core.display import HTML

def css_styling():
    styles = open("../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
