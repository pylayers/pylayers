# %%
# %matplotlib inline
from matplotlib.pyplot import *
from IPython.display import Image
from pylayers.gis.layout import *
from pylayers.mobility.ban.body import *
# Out:
# WARNING:traits.has_traits:DEPRECATED: traits.has_traits.wrapped_class, 'the 'implements' class advisor has been deprecated. Use the 'provides' class decorator.

# %% [markdown]
# <center>
# <h1 class="title"><font color="#2201FF">Indoor On-body Channel Ray Tracing and Motion Capture Based Simulation</font></h1>
# <h2 class="title"> IC1004 COST Meeting Aalborg 2014</h2>
# <h2> Meriem Mhedhbi,  Nicolas Amiot, Stéphane Avrillon, <u>Bernard Uguen</u></h2>
#
# </center>

# %% [markdown]
# <h1><font color="#2201FF">http://tinyurl.com/pr65ujz</font></h1>

# %% [markdown]
# <div>
#
# <img class="logo" src="./files/images/logo.png" height=10>
#
# </div>

# %% [markdown]
# <h1 class="title">Outline </h1>

# %% [markdown]
# * Introduction
# * Scenarios of the ANR CORMORAN project
# * Description of Measurements Campaign from [Nicta Lab Data](http://tinyurl.com/jwp55gs) [[Smith11]](http://www.nicta.com.au/pub?doc=3430)
# * [PyLayers](http://pylayers.github.io/pylayers) Simulation Setup
# * Measurements vs Simulation
# * Conclusions and Perspectives

# %% [markdown]
# <h1 class="title"> CORMORAN Project Context</h1>

# %% [markdown]
# + To produce test vectors for WBAN localization algorithms
#     + LSIMC (Large Scale **Individual** Motion Capture)
#     + CGN (Coordinated Group Navigation)

# %% [markdown]
# <h1 class="title"> CORMORAN Project Context (Scenario LSIMC)</h1>

# %% [markdown]
# <center>
# <div>
# <img class="logo" src="./files/LSIMC.png" height=250 width=250/>
# <h2> Large Scale Individual Motion Capture [CORMORAN-D11]</h2>
# </div>
# </center>

# %% [markdown]
# <h1 class="title"> CORMORAN Project Context (Scenario CGN)</h1>

# %% [markdown]
# <center>
# <div>
# <img class="logo" src="./files/CGN.png" height=550 width=550/>
# <h2> Large Scale Individual Motion Capture [CORMORAN-D11]</h2>
# </div>
# </center>

# %% [markdown]
# <h1 class="title"> Measurement Setup (1) </h1>

# %% [markdown]
# * **Configuration**: On Body Walking
# * **Frequency**  : 2.36 GHz
# * **Environment** : Indoor Office
# * VSA vector signal analysis **sampled for approximately 10 s**

# %% [markdown]
# Channel measurements were performed by transmitting test signals emanating from a VSA centered in regions around the
# 400-, 900-, and 2,400-MHz ISM bands, specifically 427,
# 820, and 2,360 MHz. The test signals were separately
# transmitted from one antenna while the 181.5-cm/78-kg
# male test subject performed three different actions:
# + (1) standing still
# + (2) walking on the spot,
# + (3) running on the spot.

# %% [markdown]
# <center>
# <div>
# <img src="./files/environment.png" height=400 width=400/>
# <h2> Layout of the environement setup from [Smith11]</h2>
# </div>
# </center>

# %% [markdown]
# <h1 class="title"> Measurement Setup (2) </h1>

# %% [markdown]
# * Subject moving on a treadmill
# * Walking scenario: speed  = 3km/h during 10s
# * Devices On-body configuration
# * Antenna : [Octane BW-2400-2500](http://www.pharad.com/pdf/WLAN-Wearable-Antenna-Datasheet.pdf)

# %% [markdown]
# <center>
# <div>
# <table>
# <tr><tcl><img src="./files/devLoc.png" height="50" width="200" /></tcl>
# </table>
# </div>
# <h3>Positions of the radio devices from [Smith2011]</h3>
# </center>

# %% [markdown]
# <h1 class="title">Simulation Setup (1)</h1>

# %% [markdown]
# + Layout and Propagation Environment
#     + Furnitures are not modeled (treadmill)
# + Large Scale and Body Scale Mobility
#     + Pylayers handles large scale mobility: agent = gravity center
#     + Body Scale Mobility is plugged using a motion capture files
#     + Centered trajectory to simulate walking on treadmill (speed = 3km/h)

# %% [markdown]
# <h1 class="title">Simulation Setup (Body Configuration fine `John.ini`)</h1>

# %%
[nodes]
0 = STRN
1 = CLAV
2 = RFHD 
3 =RSHO 
4 =LSHO
5 =RELB 
6 =LELB 
7 =RWRB 
8 =LWRB
9 =RFWT
10 =LFWT 
11 =RKNE
12 =LKNE 
13 =RANK 
14 =LANK 
15 =BOTT 
[cylinder]
; sternum (STRN) - clavicle (CLAV)
trunku = {'t':15,'h':1,'r':0.18,'i':0}
; bottom  (BOTT) sternum (STRN)  
trunkb = {'t':15,'h':0,'r':0.17,'i':10}
; clavicle (CLAV)  - head (RFHD)
headu = {'t':1,'h':2,'r':0.12,'i':1}
; right elbow (RELB)  right shoulder (RSHO)
armr = {'t':5,'h':3,'r':0.05,'i':2}
; left elbow (LELB)  left shoulder (LSHO)
arml  = {'t':6,'h':4,'r':0.05,'i':3}
; right wrist (RWRB) right elbow (RELB)  
forearmr = {'t':7,'h':5,'r':0.05,'i':4}
; left wrist (LWRB)  left elbow (LELB)  
forearml = {'t':8,'h':6,'r':0.05,'i':5}
; right knee (RKNE) right hip (RFWT)  
thighr = {'t':11,'h':9,'r':0.05,'i':6}
; left knee (LKNE)  left hip (LFWT)  
thighl = {'t':12,'h':10,'r':0.05,'i':7}
; right ankle (RANK) right knee (RKNE)  
calfr = {'t':13,'h':11,'r':0.05,'i':8}
; left ankle (LANK) left knee (LKNE)  
calfl = {'t':14,'h':12,'r':0.05,'i':9}
[device]
; front chest device 
0 = {'typ':'static','name':'cardio','cyl':'trunku','l':0.8,'h':0.01,'a':0,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; back chest device
1 = {'typ':'static','name':'generic','cyl':'trunku','l':0.5,'h':0.01,'a':180,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; right hip device 
2 = {'typ':'static','name':'generic','cyl':'trunku','l':0.1,'h':0.01,'a':340,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; left hip device 
3 = {'typ':'static','name':'generic','cyl':'trunku','l':0.1,'h':0.01,'a':20,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; right wrist device 
4 = {'typ':'dynamic','name':'watch','cyl':'forearmr','l':0.2,'h':0.01,'a':260,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; left wrist device 
5 = {'typ':'dynamic','name':'watch','cyl':'forearml','l':0.2,'h':0.01,'a':100,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
;right ankle device
6 = {'typ':'dynamic','name':'generic','cyl':'calfr','l':0.2,'h':0.01,'a':0,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
;right ankle device
7 = {'typ':'dynamic','name':'generic','cyl':'calfl','l':0.2,'h':0.01,'a':0,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
[mocap]
walk = '07_01_c3d'
# Out:
#   File "<ipython-input-2-c8f1e581093b>", line 2
#     0 = STRN
# SyntaxError: can't assign to literal

# %% [markdown]
# <h1 class="title">Configuration of the Body File</h1>

# %%
John=Body('Bernard.ini')
John
# Out:
# **** Processor coding : DEC-VAX
# My name is : Bernard
#
# I have a TCR device with id #TCR:48 on LWrist
# I have a TCR device with id #TCR:34 on RHeadNode
# I have a TCR device with id #TCR:35 on BChestNode
# I have a TCR device with id #TCR:36 on RAnk
# I have a TCR device with id #TCR:37 on LAnk
# I have a TCR device with id #TCR:30 on LFChestNode
# I have a TCR device with id #TCR:26 on RWrist
# I have a TCR device with id #TCR:25 on RFChestNode
# I have a TCR device with id #TCR:33 on LKnee
# I have a TCR device with id #TCR:2 on LChestNode
#
# I am nowhere yet
#
# filewear : Bernard_11-06-2014_TCR.ini
# filename : serie_017.c3d
# nframes : 11213
# Centered : True
# Mocap Speed : 0.141 m/s

# %%
# %load ~/Bureau/P1/ini/Bernard.ini

# %%
[nodes]
0 = STRN
1 = CLAV
2 = RFHD 
3 =RSHO 
4 =LSHO
5 =RELB 
6 =LELB 
7 =RWRB 
8 =LWRB
9 =RFWT
10 =LFWT 
11 =RKNE
12 =LKNE 
13 =RANK 
14 =LANK 
15 =BOTT 
[cylinder]
; sternum (STRN) - clavicle (CLAV)
trunku = {'t':15,'h':1,'r':0.18,'i':0}
; bottom  (BOTT) sternum (STRN)  
trunkb = {'t':15,'h':0,'r':0.17,'i':10}
; clavicle (CLAV)  - head (RFHD)
headu = {'t':1,'h':2,'r':0.12,'i':1}
; right elbow (RELB)  right shoulder (RSHO)
armr = {'t':5,'h':3,'r':0.05,'i':2}
; left elbow (LELB)  left shoulder (LSHO)
arml  = {'t':6,'h':4,'r':0.05,'i':3}
; right wrist (RWRB) right elbow (RELB)  
forearmr = {'t':7,'h':5,'r':0.05,'i':4}
; left wrist (LWRB)  left elbow (LELB)  
forearml = {'t':8,'h':6,'r':0.05,'i':5}
; right knee (RKNE) right hip (RFWT)  
thighr = {'t':11,'h':9,'r':0.05,'i':6}
; left knee (LKNE)  left hip (LFWT)  
thighl = {'t':12,'h':10,'r':0.05,'i':7}
; right ankle (RANK) right knee (RKNE)  
calfr = {'t':13,'h':11,'r':0.05,'i':8}
; left ankle (LANK) left knee (LKNE)  
calfl = {'t':14,'h':12,'r':0.05,'i':9}
[device]
; 0 front chest device 
0 = {'typ':'static','name':'cardio','cyl':'trunku','l':0.8,'h':0.01,'a':0,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; 1 back chest device
1 = {'typ':'static','name':'generic','cyl':'trunku','l':0.5,'h':0.01,'a':180,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; 2 right hip device 
2 = {'typ':'static','name':'generic','cyl':'trunku','l':0.1,'h':0.01,'a':340,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; 3 left hip device 
3 = {'typ':'static','name':'generic','cyl':'trunku','l':0.1,'h':0.01,'a':20,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; 4 right wrist device 
4 = {'typ':'dynamic','name':'watch','cyl':'forearmr','l':0.2,'h':0.01,'a':260,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; 5 left wrist device 
5 = {'typ':'dynamic','name':'watch','cyl':'forearml','l':0.2,'h':0.01,'a':100,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; 6 right ankle device
6 = {'typ':'dynamic','name':'generic','cyl':'calfr','l':0.2,'h':0.01,'a':0,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
; 7right ankle device
7 = {'typ':'dynamic','name':'generic','cyl':'calfl','l':0.2,'h':0.01,'a':0,'file':'S17R2m.sh3','T':np.array([[1,0,0],[0,1,0],[0,0,1]])}
[mocap]
walk = '07_01_c3d'

# %% [markdown]
# <h1 class="title">Simulation Setup (Devices file `devices.json`)</h1>

# %%
# %load /home/uguen/Bureau/P1/ini/devices.json

# %%
{
    "Glass": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "defant.vsh3",
                "p": [
                    0.0,
                    0.0,
                    1.0
                ]
            }
        },
        "dimensions": {
            "depth": 3.5,
            "height": 150.0,
            "width": 148.0
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A1"
                ]
            },
            "ieee80211a": {
                "antenna": [
                    "A1"
                ]
            },
            "ieee80211b": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "Router": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "defant.vsh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 202.0,
            "height": 160.0,
            "width": 34.0
        },
        "standards": {
            "ieee80211a": {
                "antenna": [
                    "A1"
                ]
            },
            "ieee80211b": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "Telephone": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "S2R2.sh3",
                "p": "[0.5, 0.5, 0.5]"
            },
            "A2": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "defant.vsh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 7.6,
            "height": 123.8,
            "width": 58.6
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A2"
                ]
            },
            "ieee80211a": {
                "antenna": [
                    "A1"
                ]
            },
            "ieee80211b": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "Galaxy Gear": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "S2R2.sh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 11.1,
            "height": 36.8,
            "width": 56.6
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "cardio": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "S2R2.sh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 11.1,
            "height": 36.8,
            "width": 56.6
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "generic": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "S17R2m.sh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 11.1,
            "height": 36.8,
            "width": 56.6
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A1"
                ]
            }
        }
    }
}

# %%
{
    "Glass": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "defant.vsh3",
                "p": [
                    0.0,
                    0.0,
                    1.0
                ]
            }
        },
        "dimensions": {
            "depth": 3.5,
            "height": 150.0,
            "width": 148.0
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A1"
                ]
            },
            "ieee80211a": {
                "antenna": [
                    "A1"
                ]
            },
            "ieee80211b": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "Router": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "defant.vsh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 202.0,
            "height": 160.0,
            "width": 34.0
        },
        "standards": {
            "ieee80211a": {
                "antenna": [
                    "A1"
                ]
            },
            "ieee80211b": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "Telephone": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "S2R2.sh3",
                "p": "[0.5, 0.5, 0.5]"
            },
            "A2": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "defant.vsh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 7.6,
            "height": 123.8,
            "width": 58.6
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A2"
                ]
            },
            "ieee80211a": {
                "antenna": [
                    "A1"
                ]
            },
            "ieee80211b": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "Galaxy Gear": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "S2R2.sh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 11.1,
            "height": 36.8,
            "width": 56.6
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "cardio": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "S2R2.sh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 11.1,
            "height": 36.8,
            "width": 56.6
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A1"
                ]
            }
        }
    },
    "generic": {
        "antennas": {
            "A1": {
                "T": "[1.,0.,0.],[0.,1.,0.],[0.,0.,1.]",
                "name": "S17R2m.sh3",
                "p": [
                    0.5,
                    0.5,
                    0.5
                ]
            }
        },
        "dimensions": {
            "depth": 11.1,
            "height": 36.8,
            "width": 56.6
        },
        "standards": {
            "bluetooth-class2": {
                "antenna": [
                    "A1"
                ]
            }
        }
    }
}

# %% [markdown]
# <h1 class="title">Simulation Setup (Motion Capture) </h1>

# %% [markdown]
# Motion capture file **07_01.c3d** from [Cmu graphics lab motion capture database]( http://mocap.cs.cmu.edu/search.php?subjectnumber=%&motion=%)

# %% [markdown]
# <center>
# <div>
# <img class="logo" src="./files/07_01c3d.png" height=100 />
# <h2> Walking Motion Capture Sequence 07_01.c3d</h2>
# </div>
# </center>

# %% [markdown]
# <h1 class="title">Simulation Setup : Body Perturbed Antenna Model in Spherical Harmonics space</h1>

# %% [markdown]
# <center>
# <div>
# <img src="./files/coeff_lm.png" height=800 width=800/>
# <h3>Evolution of Spherical Harmonics Coeff w.r.t cylinder phantom (radius=10cm) distance  [Mhed14] </h3>
# </div>
# </center>

# %% [markdown]
# <h1 class="title">Simulation Setup : Body Perturbed Antenna Model in Spherical Harmonics space</h1>

# %% [markdown]
# <center>
# <div>
# <img class="logo" src="./files/octaneFS.png" height=1500 width=1500 />
# <h4> Free space antenna pattern f= 2.6GHz</h4>
# <img class="logo" src="./files/octaneP.png" height=1500 width=1500/>
# <h4> Perturbed antenna pattern f= 2.6GHz</h4>
# </div>
# </center>

# %% [markdown]
# <h1 class="title">Pluging all together and checking with `Mayavi`</h1>

# %% [markdown]
# <center>
# <div>
# <img src="./files/snapJohn1.png" height="400" width="400" />
# </div>
# <h3>Positions of the radio devices along a synthetic trajectory</h3>
# </center>

# %% [markdown]
# <h1 class="title">Body + Trajectory + Devices + Antennas => Topos</h1>

# %% [markdown]
# <center>
# <div>
# <img  src="./files/snapshot5.png" height="500" width="500"/>
# </div>
# <h3>Positions of the body equipped with radio devices along a synthetic trajectory</h3>
# </center>

# %% [markdown]
# <h1 class="title">Measurements vs Simulation</h1>

# %%
# %matplotlib inline
import h5py
from numpy import *
from matplotlib.pyplot import *
from pylayers.util.CDF import *

# %% [markdown]
# Reading the data file

# %%
onbody = h5py.File('onbody.h5','r')

# %% [markdown]
# Selecting the link : walking , bandwidth=10MHz, f = 2.36GHz

# %% [markdown]
# **HDF5** file structure

# %% [markdown]
# + 100K
#     - 2d36G
#         + Running
#         + Standing
#         + Walking
#     - 427M
#         + Running
#         + Standing
#         + Walking
# + 10M
#     - 2d36G
#         + running
#         + standing
#         + **walking**
#     - 427M
#         + running
#         + standing
#         + walking
#     - 820M
#         + running
#         + standing
#         + walking

# %% [markdown]
# <h2>Selecting the measured Link in hdf5 file</h2>

# %%
bw   = '10M'
freq = '2d36G'
mov  = 'walking'
links  = onbody[bw][freq][mov]

# %%
#f  = h5py.File('./simultraj_traj_nicta_off_180.h5','r')
import pylayers.signal.bsignal as bs
f  = h5py.File('./simultraj_traj_nicta_ds.h5','r')

fkeys = f.keys()

slinks = []
for key in fkeys:
    slink = key.split('_')[1]+'_'+key.split('_')[2]+'_'+key.split('_')[3]+'_'+key.split('_')[4]
    if slink not in slinks:
        slinks.append(slink)
#print 'links = ', links

taumin = 0
taumax = 50
taustep = 0.1
CIR = []
sllink = ['0_John_1_John',
         '2_John_1_John',
         '0_John_2_John',
         '7_John_2_John',
         '5_John_2_John',
         '6_John_0_John',
         '6_John_2_John',
         '4_John_0_John',
         '4_John_2_John'
        ]

# agregation of path CIR 

for slink in sllink:
    print 'link = ', slink
    r = filter(lambda x:x.split('_')[1:5]==slink.split('_')[0:4],fkeys)
    x = np.arange(taumin,taumax,taustep)
    y = np.zeros(len(x))
    cira=bs.TUsignal(x,y)
    for k in range(len(r)):
        key = filter(lambda x:int(x.split('_')[0])==k,r)
        ak = f[key[0]]['alphak'].value
        tk = f[key[0]]['tauk'].value
        cira.aggcir(ak,tk)
    CIR.append(cira)
    
    
fig = plt.figure(figsize=(10,10))
t = linspace(0,10,4000)
ts = linspace(0,14,140)
u5 = np.where(ts<=5)

for i,k in enumerate(links):
    pl = links[k]['pl'].value
    pls = 10*np.log10(np.sum(abs(CIR[i].y)**2, axis= 1))[3:]
    tt = str(k).replace('pl_','')
    tt = tt.replace('_','/')
    col='b'
    if tt=='leftwrist/righthip':
        col='g'
    if tt=='rightwrist/righthip':
        col='g'
    if tt=='back/chest':
        col='r'
    ax = fig.add_subplot(3,3,i,title=tt)
    ax.title.set_fontsize(18)
    xlabel('Time (s)')
    ylabel('Path Loss (dB)')
    axis((0,5,-80,-30))
    ax.plot(t,pl,linewidth=2,color=col)

    ax.plot(ts[u5],pls[u5],linewidth=2,color='k')
plt.tight_layout()    
savefig('./files/OnBodyWalking2d6G.png')
# Out:
# link =  0_John_1_John
# link =
#  2_John_1_John
# link =
#  0_John_2_John
# link =
#  7_John_2_John
# link =
#  5_John_2_John
# link =
#  6_John_0_John
# link =
#  6_John_2_John
# link =
#  4_John_0_John
# link =
#  4_John_2_John

# %%
fig = plt.figure(figsize=(10,10))
for i,k in enumerate(links):
    tt = str(k).replace('pl_','')
    tt = tt.replace('_','/')
    ax = fig.add_subplot(3,3,i,title=tt)
    CIR[i].imshow(cmap='jet',ax=ax,fig=fig)

# %% [markdown]
# <div>
# <center>
# <img  src="./files/OnBodyWalking2d6G.png" height=800 width=800>
# <h2>Walking OnBody 10MHz 2.36GHz, Evolution of Path Loss over 5 s (from NICTA data)</h2>
# </center>
# </div>

# %% [markdown]
# <div>
# <center>
# <img class="logo" src="./files/pathlossNICTA.png" height=500 width=500>
# <h4>Walking OnBody 10MHz 2.36GHz, Evolution of Path Loss over 10 s (from NICTA data)</h4>
# <img class="logo" src="./files/pathlossSim.png" height=500 width=500>
# <h4>Walking OnBody 10MHz 2.36GHz, Evolution of Path Loss over 10 s (from PyLayers Simulation)</h4>
# </center>
# </div>

# %% [markdown]
# <div>
# <center>
# <img class="logo" src="./files/cdfNICTA.png" height=500 width=500>
# <h4>Walking OnBody 10MHz 2.36GHz, Evolution of Path Loss over 10 s (from NICTA data)</h4>
# <img class="logo" src="./files/cdfSimul.png" height=500 width=500>
# <h4>Walking OnBody 10MHz 2.36GHz, Evolution of Path Loss over 10 s (from PyLayers Simulation)</h4>
# </center>
# </div>

# %% [markdown]
# <h1 class="title">Measurements vs Simulation</h1>

# %% [markdown]
# <div>
# <center>
# <img class="logo" src="./files/OnBodyWalking2d6G.png" height=500 width=500>
# <h4>Walking OnBody 10MHz 2.36GHz, Evolution of Path Loss over 5 s (from NICTA data)</h4>
# </center>
# </div>

# %%
llinks  =  links.keys()
cm = plt.get_cmap('gist_rainbow')
markers = [ '.', ',','o','v','^','<','>','1','2','3','4','8','s','p','*','h','H','+','x','D','d','|','_']
ld  = []
figure(figsize = (15,10))
ll =  llinks
pathloss= []
time = np.linspace(0,10,4000)
for i in range(0,len(ll)):
    dic = {}
    lk  = llinks[i] 
    pl = links[lk]['pl'].value    
    pathloss.append(pl-mean(pl))
    plot(time,pl, label = str(llinks[i]).replace('_','-'), color =cm(1.*i/len(ll)) )
    dic['values']= pl
    dic ['bound']= np.arange(-80,-40,1)
    dic['xlabel'] = 'Path Loss in dB'
    dic['ylabel'] = 'CDF'
    dic['legend'] = str(llinks[i]).replace('_','-')
    dic['markersize'] = 4
    dic['markercolor'] = cm(1.*i/len(ll))
    dic['linestyle'] = '-'
    dic['color'] = cm(1.*i/len(ll))
    dic['markerfrequency'] = 1
    dic['title'] = 'link '
    dic['marker'] = markers[i]
    dic['linewidth'] = 1
    ld.append(dic)
xticks(fontsize=20)
yticks(fontsize=20)
legend()
grid()
xlabel('Time (s)', fontsize =18)
ylabel('Path Loss (dB)', fontsize =18)

savefig('pathlossNICTA.png')
figure(figsize = (15,10))

# %%
#import pylayers.simul.simultraj as st
import h5py
import pylayers.signal.bsignal as bs
import numpy as np
import sys
import matplotlib.pyplot as plt
from pylayers.util.CDF import *

#f  = h5py.File('./simultraj_traj_nicta_off_180.h5','r')
f  = h5py.File('./simultraj_traj_nicta_ds.h5','r')

fkeys = f.keys()
nodes  = []
for key in fkeys:
    nodek = key.split('_')[1]+'_'+key.split('_')[2]
    if nodek not in nodes:
        nodes.append(nodek)

#print 'node  = ', nodes
links = []
for key in fkeys:
    link = key.split('_')[1]+'_'+key.split('_')[2]+'_'+key.split('_')[3]+'_'+key.split('_')[4]
    if link not in links:
        links.append(link)
#print 'links = ', links

taumin = 0
taumax = 300
taustep = 0.1
CIR = []
llink = links
llink = ['0_John_1_John',
         '2_John_1_John',
         '0_John_2_John',
         '7_John_2_John',
         '5_John_2_John',
         '6_John_0_John',
         '6_John_2_John',
         '4_John_0_John',
         '4_John_2_John'
        ]
#~ llink = ['0_John_4_John','2_John_4_John','0_John_2_John']

markers = [
        '.',
        ',',
        'o',
        'v',
        '^',
        '<',
        '>',
        '1',
        '2',
        '3',
        '4',
        '8',
        's',
        'p',
        '*',
        'h',
        'H',
        '+',
        'x',
        'D',
        'd',
        '|',
        '_']

for slink in sllink:
    print 'link = ', slink
    r = filter(lambda x:x.split('_')[1:5]==link.split('_')[0:4],fkeys)
    x = np.arange(taumin,taumax,taustep)
    y = np.zeros(len(x))
    cira=bs.TUsignal(x,y)
    for k in range(len(r)):
        key = filter(lambda x:int(x.split('_')[0])==k,r)
        ak = f[key[0]]['alphak'].value
        tk = f[key[0]]['tauk'].value
        cira.aggcir(ak,tk)
    CIR.append(cira)


#### CDF
cm = plt.get_cmap('gist_rainbow')
ld  = []
pathloss = []
plt.figure(figsize=(15,10))
for i in range(len(CIR)):
    dic = {}
    pl = 10*np.log10(np.sum(abs(CIR[i].y)**2, axis= 1))[3:]
    #pl = 10*np.log10((abs(CIR[i].y)**2))
    pathloss.append(pl)
    #plt.plot(pl, label = str(llink[i]).replace('_','-'), color =cm(1.*i/len(CIR)))
    #~ plt.plot(np.arange(0,10,0.1),pl[0:100], label = '', color =cm(1.*i/len(CIR)))
    plt.plot(pl, label = '', color =cm(1.*i/len(CIR)))
    plt.ylim([-80,-40])
    dic['values']= pl
    dic ['bound']= np.arange(-80,-34,1)
    dic['xlabel'] = 'pathloss in dB'
    dic['ylabel'] = 'CDF'
    dic['legend'] =  str(llink[i]).replace('_','-')
    dic['markersize'] = 4
    dic['markercolor'] = cm(1.*i/len(CIR))
    dic['linestyle'] = '-'
    dic['color'] = cm(1.*i/len(CIR))
    dic['markerfrequency'] = 1
    dic['title'] = 'link '
    dic['marker'] =  markers[i]
    dic['linewidth'] = 1
    ld.append(dic)
plt.legend()
plt.grid()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('time (s)', fontsize=18)
plt.ylabel('path loss (dB)', fontsize = 18)
c = CDF(ld, 'fig')
c.show()
#~ pathloss = np.array(pathloss)
#~ sh = pathloss.shape
#~ pathloss = pathloss.reshape((sh[0]*sh[1]))
#~ plt.figure()
#~ plt.hist(pathloss, bins= 50)




plt.show()

# %%
c = CDF(ld,'cdf')
c.show()
savefig('cdfNICTA.png')

# %% [markdown]
# <h1 class="title">Conclusion and Perspectives </h1>

# %% [markdown]
# + Demonstration of the utilization of the PyLayers platform in a WBAN context.
# + Simple and fast implementation is required when adressing upper layer abstaction (PHY and MAC)
# + **Claim**: Associating motion capture file and body pertubed antenna model allows to recover the multi links onbody channel gain.
# + NICTA measurment has to be investigated on more scenario
# + NICTA measurement can be used for calibration of perturbed antenna in the spherical harmonics domain.
# + Association of radio data and body motion capture from a **same subject**

# %% [markdown]
# <h1 class="title">References</h1>
#
# **[Smith11]** David B. Smith, Leif Hanlen, Jian (Andrew) Zhang, Dino Miniutti, David Rodda, and Ben
# Gilbert. [*First- and second-order statistical characterizations of the dynamic body area propagation channel of various bandwidths*](http://www.nicta.com.au/pub?doc=3430). Annales des T ́l ́communications, 66(3-4):187–203,
# ee
# 2011.
#
# **[NictaData]** Nicta body area network radio channel data. http://tinyurl.com/jwp55gs.
#
# **[Mhed14]** Meriem Mhedhbi, Stéphane Avrillon, Troels Pedersen, and Bernard Uguen.
# [*Modelling of UWB antenna perturbed by human phantom in spherical harmonics space*](http://vbn.aau.dk/files/195257751/1569855541.pdf). In The 8th European
# Conference on Antennas and Propagation (EuCAP 2014) (EuCAP 2014), The Hague, The
# Netherlands, April 2014
#
# **[MotionCapture]** [Cmu graphics lab motion capture database : Subject 7: walk (0701.c3d).]( http://mocap.cs.
# cmu.edu/search.php?subjectnumber=%&motion=%)

# %%
from IPython.display import display, HTML
s = """

<style>

.rendered_html {
    font-family: "proxima-nova", helvetica;
    font-size: 150%;
    line-height: 1.3;
}

.rendered_html h1 {
    margin: 0.25em 0em 0.5em;
    color: #015C9C;
    text-align: center;
    line-height: 1.2; 
    page-break-before: always;
}

.rendered_html h2 {
    margin: 1.1em 0em 0.5em;
    color: #26465D;
    line-height: 1.2;
}

.rendered_html h3 {
    margin: 1.1em 0em 0.5em;
    color: #002845;
    line-height: 1.2;
}

.rendered_html li {
    line-height: 1.5; 
}

.prompt {
    font-size: 120%; 
}

.CodeMirror-lines {
    font-size: 120%; 
}

.output_area {
    font-size: 120%; 
}

notebook {
    background-image: url('files/images/background.png');
}

h1.bigtitle {
    margin: 4cm 1cm 4cm 1cm;
    font-size: 300%;
}

h3.point {
    font-size: 200%;
    text-align: center;
    margin: 2em 0em 2em 0em;
    #26465D
}

.logo {
    margin: 20px 0 20px 0;
}

a.anchor-link {
    display: none;
}

h1.title { 
    font-size: 250%;
}

</style> Morbihan énergies
"""
display(HTML(s))
