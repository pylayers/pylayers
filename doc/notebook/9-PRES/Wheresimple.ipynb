# %%
from pylayers.measures.mesuwb import *
from pylayers.simul.link import *
from pylayers.signal.waveform import *
# Out:
# Warning : OSM Parser seems to be not installed

# %%
L=Layout('WHERE2.ini')
L.dumpr()

# %%
# measure id
tx_id = 40 # in M.valid_index
rx_id = 2 # 1,2,3,4
M=UWBMeasure(rx_id)

TX = M.tx
RX = M.rx[rx_id]

# %%
L.showG('s',figsize=(20,20))
plt.plot(TX[0],TX[1],'ob')
plt.plot(RX[0],RX[1],'or')

# %%
Lk = DLink(L=L,a=TX,b=RX,cutoff=3,verbose=False)
Lk.Aa=Antenna('defant.vsh3')
Lk.Ab=Antenna('defant.vsh3')
Lk.eval()
f,a = Lk.show(rays=True,labels=False)

# %%
wav = Waveform(typ='W1compensate')
ir = Lk.H.applywavB(wav.sfg)

# %%
fig = plt.figure(figsize=(20,20))
ax1=fig.add_subplot(211)
cmd='M.tdd.ch' + str(rx_id) + '.plot(typ=\'v\',fig=fig,ax=ax1)'
eval(cmd)

ax2 = fig.add_subplot(212,sharex=ax1)
ir.plot(typ='v',fig=fig,ax=ax2)
# Out:
# (<matplotlib.figure.Figure at 0x101b7550>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x98e3390>]], dtype=object))
