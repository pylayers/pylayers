# %%
import pylayers.gis.ezone as ez
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# %%
prefix=ez.enctile(-1.5,47.5)
print prefix
# Out:
# N47W002

# %%
E=ez.Ezone(prefix)

# %%
E
# Out:
# N47W002
# --------
# (-2, -1, 47, 48)
# latlon : [ -0.000 75118.790 cartesian :0.000 111194.505 ]

# %%
E.getdem()
# Out:
# Load srtm file
# no aster file for this point

# %%
E.show(clim=[-20,180])
# Out:
# (<matplotlib.figure.Figure at 0x2b2cacd17d90>,
#  <matplotlib.axes.AxesSubplot at 0x2b2cacd2f2d0>)

# %%
E
# Out:
# N47W002
# --------
# (-2, -1, 47, 48)
# latlon : [ -0.000 75118.790 cartesian :0.000 111194.505 ]
