# %% [markdown]
# ## Building the graph of rooms

# %%
from pylayers.gis.layout  import *
import matplotlib.pyplot as plt
import pylayers.util.geomutil as geu
import networkx as nx
import copy

# %% [markdown]
# Load WHERE1 Layout and build the graph Gt

# %%
L = Layout('WHERE1.ini')
L.buildGt()
# Out:
# WARNING:root:first decompose run failed

# %%
fig = plt.figure(figsize=(20,20))
L.showG('t',labels=True,font_size=14,fig=fig)
plt.axis('off')
# Out:
# (-40.0, 40.0, 2.0, 18.0)

# %%
L.Gt.neighbors(5)
# Out:
# [4]

# %%
L.Gt.edge[5]
# Out:
# {4: {'segment': array([  3,   9, 340])}}

# %% [markdown]
# Cycle 5 has 8 neighbors. Cycle 22 is only connected with one point.

# %%
Ga = nx.Graph()
Ga.pos ={}
for k in L.Gt.edge:
    dk = L.Gt.edge[k]
    for cy in dk:
        try:
            segs = dk[cy]['segment']
        except:
            segs=[]
        for s in segs:
            if L.Gs.node[s]['name']=='AIR':
                if k not in Ga.node:
                    Ga.add_node(k)
                    Ga.pos[k]=L.Gt.pos[k]
                if cy not in Ga.node:
                    Ga.add_node(cy)
                    Ga.pos[cy]=L.Gt.pos[cy]
                Ga.add_edge(k,cy)

# %%
fig = plt.figure(figsize=(20,20))
L.showG('s',fig=fig)
plt.axis('off')
nx.draw(Ga,Ga.pos)

# %%
connected =nx.connected_components(Ga)
print connected
# Out:
# [[43, 44, 38], [77, 6, 21], [8, 24, 23], [73, 29, 30], [57, 58], [33, 26], [74, 75], [51, 54]]

# %%
H=Ga.subgraph([44,45,39])
nx.dfs_successors(H)
# Out:
# {}

# %%
Gr = copy.deepcopy(L.Gt)

# %%
Gr.node[5]['cycle']
# Out:
# cycle nstr[ 340 -287    3 -282    9 -283  343 -288]
# point number 4
# segment number 4
# area : 0.0447995
# centroid : [-22.97844626  15.98425194]

# %%
Gr = copy.deepcopy(L.Gt)
for licy in connected:
    H = Ga.subgraph(licy)
    dsucc = nx.dfs_successors(H) 
    for ncy in dsucc:
        for cy in dsucc[ncy]:
            neigh = nx.neighbors(Gr,cy)
            Gr.node[ncy]['cycle']+=Gr.node[cy]['cycle']
            for k in neigh:
                Gr.add_edge(ncy,k)       
            Gr.remove_node(cy)
        Gr.pos[ncy]=tuple(Gr.node[ncy]['cycle'].g)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-a149b948d835> in <module>()
#       6         for cy in dsucc[ncy]:
#       7             neigh = nx.neighbors(Gr,cy)
# ----> 8             Gr.node[ncy]['cycle']+=Gr.node[cy]['cycle']
#       9             for k in neigh:
#      10                 Gr.add_edge(ncy,k)
#
# KeyError: 23

# %%
fig = plt.figure(figsize=(20,20))
ax = gca()
L.showG('s',fig=fig,ax=ax,nodes=False)
plt.axis('off')
nx.draw(Gr,Gr.pos)

# %%
ltrans=L.listtransition

# %%
a = Gr.node[78]['cycle']

# %%
a.show()
# Out:
# (<matplotlib.figure.Figure at 0x49fc6d0>,
#  <matplotlib.axes.AxesSubplot at 0x4b77050>)

# %%
ldoors = filter(lambda x:L.Gs.node[x]['name']<>'AIR',ltrans)

# %% [markdown]
# Destroy cycles which have no doors

# %%
keys = Gr.node.keys()
for cy in keys:
    lseg = Gr.node[cy]['cycle'].cycle
    hasdoor = filter(lambda n : n in ldoors,lseg)
    if len(hasdoor)>0:
        pass
    else:
        Gr.remove_node(cy)

# %%
fig = plt.figure(figsize=(20,20))
ax = gca()
L.showG('s',fig=fig,ax=ax,nodes=False)
plt.axis('off')
nx.draw(Gr,Gr.pos)

# %%
from IPython.core.display import HTML

def css_styling():
    styles = open("../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .prompt{
#         display: None;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
