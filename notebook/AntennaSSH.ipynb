# %%
from pylayers.antprop.antenna import *
from pylayers.antprop.antssh import *

# %%
A = Antenna('S17R1.mat',directory = 'ant/UWBAN/Matfile')
A.Ftheta = A.Ftheta.reshape(A.Nf,A.Nt,A.Np)
A.Fphi = A.Fphi.reshape(A.Nf,A.Nt,A.Np)
L = 20
A = ssh(A,L=L, dsf = 1)
# Out:
# > /private/staff/i/bi/mmhedhbi/pylayers/pylayers/antprop/antssh.py(231)ssh()
# -> Etheta  =  A.Ftheta[:,::dsf,::dsf]
# (Pdb) c

# %%
A
#A.fa = A.fa*1e9
print A.Nf
# Out:
# 1

# %%
A.phi.shape
# Out:
# (180,)

# %%
print A.Fphi.shape
# Out:
# (1, 91, 180)

# %%
vi  = -50
va  = 20

# %%
figure(figsize=(10,5))
subplot(121)
imshow(20*log10(abs(A.Ftheta[0])), vmin = vi, vmax =va)
colorbar()
subplot(122)
imshow(20*log10(abs(A.Fphi[0])), vmin = vi, vmax =va)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fc570742170>

# %%
Ex, Ey,Ez =SphereToCart (A.theta, A.phi, A.Ftheta, A.Fphi, bfreq = True)

# %%
figure(figsize=(15,5))
subplot(131)
imshow(20*log10(abs(Ex[46])), vmin = vi, vmax =va)
colorbar()
subplot(132)
imshow(20*log10(abs(Ey[46])), vmin = vi, vmax =va)
colorbar()
subplot(133)
imshow(20*log10(abs(Ez[46])), vmin = vi, vmax =va)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xc822320>

# %%
L = 10
A, Y, Ypinv = ssh(A,L=L, dsf = 2)
# Out:
# 1 (104, 46, 90)
# 2 (104, 4140)

# %%
Y.shape
# Out:
# (36, 1035)

# %%
Ypinv.shape
# Out:
# (1035, 36)

# %%
r = dot(Y,Ypinv)
abs(r).max()
imshow(abs(r))
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x9aecd88>

# %%
# compute the spherical harmonics fucntions at the order L
Y,ssh_index  = SSHFunc(20,A.theta,A.phi)
# Compute the pseudo inverse of Y
pinv = sp.linalg.pinv(Y)

# %%
sh = pinv.shape
print sh
# Out:
# (16380, 441)

# %%
r = ones(sh[0])
plot(r)
c = dot(r,pinv)
rhat = dot(c,Y)
plot(rhat)

# %%
cx = A.S.Cx.s2
cy = A.S.Cy.s2
cz = A.S.Cz.s2

# %%
ex = dot(cx,Y).reshape(A.Nf,A.Nt,A.Np)
ey = dot(cy,Y).reshape(A.Nf,A.Nt,A.Np)
ez = dot(cz,Y).reshape(A.Nf,A.Nt,A.Np)

# %%
ex.shape
# Out:
# (1, 91, 180)

# %%
figure(figsize=(15,5))
subplot(131)
imshow(20*log10(abs(ex[0])), vmin = vi, vmax =va)
colorbar()
subplot(132)
imshow(20*log10(abs(ey[0])), vmin = vi, vmax =va)
colorbar()
subplot(133)
imshow(20*log10(abs(ez[0])), vmin = vi, vmax =va)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x9b3a320>

# %%
plot((abs(A.S.Cx.s2[0])))
plot(abs(A.S.Cy.s2[0]))
plot(abs(A.S.Cz.s2[0]))

# %%
A.savesh2()
# Out:
# create  /private/staff/i/bi/mmhedhbi/Bureau/P1/ant/S17R1.sh2  file

# %%
A.S.s2tos3()

# %%
plot(abs(A.S.Cz.s3[0]))

# %%
A.savesh3()
# Out:
# create  /private/staff/i/bi/mmhedhbi/Bureau/P1/ant/S17R1.sh3  file

# %%
B = Antenna('S17R1.sh3')
B.Fsynth3(theta= A.theta, phi = A.phi,pattern = True)

# %%
print B.Ftheta.shape
imshow(20*log10(abs(B.Ftheta[0])), vmin = vi, vmax =va)
colorbar()
figure()
print B.Fphi.shape
imshow(20*log10(abs(B.Fphi[0])), vmin = vi, vmax =va)
colorbar()
# Out:
# (1, 91, 180)
# (1, 91, 180)
# <matplotlib.colorbar.Colorbar instance at 0x997f758>

# %%
B.typ
# Out:
# 'sh3'

# %%
A.loadsh2()

# %%
A.S.Cx.lmax
# Out:
# 20

# %%
plot(abs(A.S.Cz.s2[0]))

# %%
A.loadsh3()
Et,Ep =A.Fsynth3(theta = A.theta,phi = A.phi )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-8dccb0196276> in <module>()
#       1 A.loadsh3()
# ----> 2 Et,Ep =A.Fsynth3(theta = A.theta,phi = A.phi )
#
# /private/staff/i/bi/mmhedhbi/pylayers/pylayers/antprop/antenna.py in Fsynth3(self, theta, phi, pattern)
#    1805         typ = self.typ#self._filename.split('.')[1]
#    1806
# -> 1807         assert typ in ['sh3','vsh3'], "Error wrong file type"
#    1808
#    1809         Nf = len(self.fa)
#
# AssertionError: Error wrong file type

# %%
A.Ftheta.shape
# Out:
# (3, 37, 72)

# %%
B.Ftheta[0].shape
# Out:
# (45, 90)

# %%
B = Antenna ('simulCEA.sh3')
B.Fsynth3(theta = A.theta,phi = A.phi)
imshow(abs(B.Ftheta[0]))

# %%
imshow(abs(A.Ftheta[0]))

# %%
k = 46
subplot(221)
imshow(abs(A.Ftheta[k]))
xlabel('phi')
ylabel('theta')
title('measured Etheta')
subplot(222)
imshow(abs(Et[k]))
xlabel('phi')
ylabel('theta')
title('Reconstruted Etheta')
subplot(223)
imshow(abs(A.Fphi[k]))
xlabel('phi')
ylabel('theta')
title('measured Ephi')
subplot(224)
imshow(abs(Ep[k]))
xlabel('phi')
ylabel('theta')
title('Reconstructed Ephi')

# %%
A.loadsh3()

# %%
Et,Ep =A.Fsynth3(theta = A.theta,phi = A.phi, typ ='sh' )

# %%
k = 46
subplot(221)
imshow(abs(A.Ftheta[k]))
xlabel('phi')
ylabel('theta')
title('measured Etheta')
subplot(222)
imshow(abs(Et[k]))
xlabel('phi')
ylabel('theta')
title('Reconstruted Etheta')
subplot(223)
imshow(abs(A.Fphi[k]))
xlabel('phi')
ylabel('theta')
title('measured Ephi')
subplot(224)
imshow(abs(Ep[k]))
xlabel('phi')
ylabel('theta')
title('Reconstructed Ephi')

# %%
a = array([[[0,1,2],[3,4,5]]])

# %%
a.shape
# Out:
# (1, 2, 3)

# %%
a
# Out:
# array([[[0, 1, 2],
#         [3, 4, 5]]])

# %%
b = a.reshape((1,(2*3)), order = 'F')

# %%
b
# Out:
# array([[0, 3, 1, 4, 2, 5]])
