# %%
from pylayers.antprop.antenna import *
from pylayers.antprop.antssh import *

# %%
#A = Antenna('S2R23.mat','ant/UWBAN/Matfile')## thomson antenna

# %%
fil=[]
fil.append('/private/staff/i/bi/mmhedhbi/Bureau/P1/ant/Export_antenna/Thomson+body_3GHz.csv')
fil.append('/private/staff/i/bi/mmhedhbi/Bureau/P1/ant/Export_antenna/Thomson+body_4GHz.csv')
fil.append('/private/staff/i/bi/mmhedhbi/Bureau/P1/ant/Export_antenna/Thomson+body_5GHz.csv')

A = Antenna(fil,ntheta=37,nphi=72)## thomson antenna 
A.theta = A.theta[:,0]*np.pi/180
A.phi = A.phi[0,:]*np.pi/180

# %% [markdown]
# $C_{lm}(d) = \alpha_m(d)C_{lm}^{fs}(d)exp(j\phi_m(d))$

# %%
print A.Ftheta.shape
imshow(abs(A.Ftheta[0]))
colorbar()
figure()
print A.Fphi.shape
imshow(abs(A.Fphi[0]))
colorbar()
# Out:
# (3, 37, 72)
# (3, 37, 72)
# <matplotlib.colorbar.Colorbar instance at 0x6514878>

# %%
A
A.fa
# Out:
# array([3, 4, 5])

# %%
L = 20
A = ssh(A,L=L)

# %%
A.S.Cy.s2.shape
# Out:
# (3, 441)

# %%
plot(abs(A.S.Cz.s2[0]))
plot(abs(A.S.Cx.s2[0]))
plot(abs(A.S.Cy.s2[0]))

# %%
A._filename = 'simulCEA.csv'

# %%
A.savesh2()
# Out:
# create  /private/staff/i/bi/mmhedhbi/Bureau/P1/ant/simulCEA.sh2  file
# /usr/local/lib/python2.7/dist-packages/scipy-0.12.0-py2.7-linux-x86_64.egg/scipy/io/matlab/mio.py:267: FutureWarning: Using oned_as default value ('column') This will change to 'row' in future versions
#   oned_as=oned_as)

# %%
A.S.s2tos3()

# %%
plot(abs(A.S.Cz.s3[0]))

# %%
A.savesh3()
# Out:
# create  /private/staff/i/bi/mmhedhbi/Bureau/P1/ant/simulCEA.sh3  file

# %%
B = Antenna('simulCEA.sh3')
B.Fsynth3(theta= A.theta, phi = A.phi,pattern = True)

# %%
print B.Ftheta.shape
imshow(abs(B.Ftheta[0]))
colorbar()
figure()
print B.Fphi.shape
imshow(abs(B.Fphi[0]))
colorbar()
# Out:
# (3, 37, 72)
# (3, 37, 72)
# <matplotlib.colorbar.Colorbar instance at 0x6d15908>

# %%
B.typ
# Out:
# 'sh3'

# %%
A.loadsh2()

# %%
plot(abs(A.S.Cz.s2[0]))

# %%
A.loadsh3()
Et,Ep =A.Fsynth3(theta = A.theta,phi = A.phi )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-8dccb0196276> in <module>()
#       1 A.loadsh3()
# ----> 2 Et,Ep =A.Fsynth3(theta = A.theta,phi = A.phi )
#
# /private/staff/i/bi/mmhedhbi/pylayers/pylayers/antprop/antenna.py in Fsynth3(self, theta, phi, pattern)
#    1805         typ = self.typ#self._filename.split('.')[1]
#    1806
# -> 1807         assert typ in ['sh3','vsh3'], "Error wrong file type"
#    1808
#    1809         Nf = len(self.fa)
#
# AssertionError: Error wrong file type

# %%
A.Ftheta.shape
# Out:
# (3, 37, 72)

# %%
B.Ftheta[0].shape
# Out:
# (45, 90)

# %%
B = Antenna ('simulCEA.sh3')
B.Fsynth3(theta = A.theta,phi = A.phi)
imshow(abs(B.Ftheta[0]))

# %%
imshow(abs(A.Ftheta[0]))

# %%
k = 46
subplot(221)
imshow(abs(A.Ftheta[k]))
xlabel('phi')
ylabel('theta')
title('measured Etheta')
subplot(222)
imshow(abs(Et[k]))
xlabel('phi')
ylabel('theta')
title('Reconstruted Etheta')
subplot(223)
imshow(abs(A.Fphi[k]))
xlabel('phi')
ylabel('theta')
title('measured Ephi')
subplot(224)
imshow(abs(Ep[k]))
xlabel('phi')
ylabel('theta')
title('Reconstructed Ephi')

# %%
A.loadsh3()

# %%
Et,Ep =A.Fsynth3(theta = A.theta,phi = A.phi, typ ='sh' )

# %%
k = 46
subplot(221)
imshow(abs(A.Ftheta[k]))
xlabel('phi')
ylabel('theta')
title('measured Etheta')
subplot(222)
imshow(abs(Et[k]))
xlabel('phi')
ylabel('theta')
title('Reconstruted Etheta')
subplot(223)
imshow(abs(A.Fphi[k]))
xlabel('phi')
ylabel('theta')
title('measured Ephi')
subplot(224)
imshow(abs(Ep[k]))
xlabel('phi')
ylabel('theta')
title('Reconstructed Ephi')
