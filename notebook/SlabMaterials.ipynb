# %%
#import mplrc.ieee.transaction
from pylayers.antprop.slab import *
from pylayers.util.project import *
import numpy as np

# %% [markdown]
# We load both a slab file and the corresponding mat file. Be careful the material which are used in the slab file should be avilable in the mat file.
# It could be intersting to check the consistency of those two files.

# %%
sl=SlabDB('matDB.ini','slabDB.ini')
fGHz= 2.4

# %% [markdown]
# The correspondance between an integer and the name of the available slabs is available in sl.di dictionnary

# %%
sl.di
# Out:
# {-1: 'METALIC',
#  0: 'ABSORBENT',
#  1: 'AIR',
#  2: 'WALL',
#  3: 'PARTITION',
#  4: 'WINDOW',
#  5: 'DOOR',
#  6: 'CEIL',
#  7: 'FLOOR',
#  8: 'WINDOW_GLASS',
#  9: 'WOOD',
#  10: '3D_WINDOW_GLASS',
#  11: 'WALLS',
#  12: 'PILLAR',
#  13: 'METAL',
#  14: 'CONCRETE_15CM3D',
#  15: 'CONCRETE_20CM3D',
#  16: 'CONCRETE_6CM3D',
#  17: 'CONCRETE_7CM3D',
#  18: 'PLASTERBOARD_10CM',
#  19: 'PLASTERBOARD_14CM',
#  20: 'PLASTERBOARD_7CM'}

# %% [markdown]
# The material database is a member of the slab , and as precedently there is a dictionnary available in order to store the association between a mat id
# and the material name.

# %%
mat = sl.mat

# %%
mat.di
# Out:
# {-1: 'METAL',
#  0: 'ABSORBENT',
#  1: 'AIR',
#  2: 'BRICK',
#  3: 'PLASTER',
#  4: 'GLASS',
#  5: 'CONCRETE',
#  6: 'REINFORCED_CONCRETE',
#  7: 'WOOD',
#  8: 'STONE',
#  9: 'SEA_WATER',
#  10: 'PLATRE-57GHz'}

# %% [markdown]
# It is posssible to easily define individual materials

# %%
lmat    = ['BRICK','AIR','BRICK']
lthick = [0.01,0.1,0.01]

# %%
theta  = arange(0,pi/2,0.01,dtype=float64)

# %%
sl.add('placo',lmat,lthick)

# %%
sl['placo'].ev(fGHz,theta)

# %%
figsize(8,8)
f,a=sl['placo'].plotwrt('a')

# %%
fGHz   = arange(0.4,8.3,0.1)
f,a=sl['placo'].plotwrt('f')

# %%
sl['placo'].pcolor()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-7475fed58322> in <module>()
# ----> 1 sl['placo'].pcolor()
#
# /home/uguen/Documents/rch/devel/pylayers/pylayers/antprop/slab.pyc in pcolor(self, dB)
#     140         plt.hot()
#     141         plt.subplot(221)
# --> 142         plt.pcolor(self.theta[0, :] * rtd, self.fGHz[:, 0], modRo)
#     143         plt.colorbar()
#     144         plt.contour(self.theta[0, :] * rtd, self.fGHz[:, 0], modRo)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/pyplot.pyc in pcolor(*args, **kwargs)
#    2771         ax.hold(hold)
#    2772     try:
# -> 2773         ret = ax.pcolor(*args, **kwargs)
#    2774         draw_if_interactive()
#    2775     finally:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/axes.pyc in pcolor(self, *args, **kwargs)
#    7375         collection.set_norm(norm)
#    7376         collection.set_clim(vmin, vmax)
# -> 7377         collection.autoscale_None()
#    7378         self.grid(False)
#    7379
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/cm.pyc in autoscale_None(self)
#     308         if self._A is None:
#     309             raise TypeError('You must first set_array for mappable')
# --> 310         self.norm.autoscale_None(self._A)
#     311         self.changed()
#     312
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/colors.pyc in autoscale_None(self, A)
#     923         ' autoscale only None-valued vmin or vmax'
#     924         if self.vmin is None:
# --> 925             self.vmin = ma.min(A)
#     926         if self.vmax is None:
#     927             self.vmax = ma.max(A)
#
# /usr/local/lib/python2.7/dist-packages/numpy/ma/core.pyc in min(obj, axis, out, fill_value)
#    5890         # If obj doesn't have a max method,
#    5891         # ...or if the method doesn't accept a fill_value argument
# -> 5892         return asanyarray(obj).min(axis=axis, fill_value=fill_value, out=out)
#    5893 min.__doc__ = MaskedArray.min.__doc__
#    5894
#
# /usr/local/lib/python2.7/dist-packages/numpy/ma/core.pyc in min(self, axis, out, fill_value)
#    5060         # No explicit output
#    5061         if out is None:
# -> 5062             result = self.filled(fill_value).min(axis=axis, out=out).view(type(self))
#    5063             if result.ndim:
#    5064                 # Set the mask
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      12 def _amin(a, axis=None, out=None, keepdims=False):
#      13     return um.minimum.reduce(a, axis=axis,
# ---> 14                             out=out, keepdims=keepdims)
#      15
#      16 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# This example is described page 90 in the thesis "Simulation du canal de propagation
# indoor " by Cyril Humbert

# %%
lmat    = ['PLATRE-57GHz','AIR','PLATRE-57GHz']
lthick = [0.018,0.03,0.018]
sl.add('Humbert',lmat,lthick)
fGHz = array([57.5])

# %% [markdown]
# This example can be found in the PhD Thesis document of Cyril Humbert humb03.pdf page 96

# %%
sl['Humbert'].ev(fGHz,theta)
sl['Humbert'].plotwrt('a')
# Out:
# (<matplotlib.figure.Figure at 0x3fd6c90>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x3ff4450>,
#         <matplotlib.axes.AxesSubplot object at 0x3b5ec10>],
#        [<matplotlib.axes.AxesSubplot object at 0x4801f90>,
#         <matplotlib.axes.AxesSubplot object at 0x3b96ad0>]], dtype=object))

# %% [markdown]
# ## Time Compensation

# %%
sl = SlabDB()

sl.mat.add(name='TESS-p50',cval=3+0j,sigma=0.06,typ='epsr')

sl.add(name='TESS-p50-5cm',lname=['TESS-p50'],lthick=[0.05])
sl.add(name='TESS-p50-10cm',lname=['TESS-p50'],lthick=[0.10])
sl.add(name='TESS-p50-15cm',lname=['TESS-p50'],lthick=[0.15])

# %%
# These Tessereau page 50 

fGHz=4
theta = np.arange(0,pi/2,0.01)

sl['TESS-p50-5cm'].ev(fGHz,theta,compensate=True)
sl['TESS-p50-10cm'].ev(fGHz,theta,compensate=True)
sl['TESS-p50-15cm'].ev(fGHz,theta,compensate=True)

# %%
# by default var='a' and kv = 0 
fig,ax = sl['TESS-p50-5cm'].plotwrt(color='k',ncol=2,nlin=2,labels=[''])
fig,ax = sl['TESS-p50-10cm'].plotwrt(color='k',ncol=2,nlin=2,labels=[''],linestyle='dashed',fig=fig,ax=ax)
fig,ax = sl['TESS-p50-15cm'].plotwrt(color='k',ncol=2,nlin=2,labels=[''],linestyle='dashdot',fig=fig,ax=ax)
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/axes.py:4601: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %%
fGHz = np.arange(2,16,0.1)
theta = 0 

sl['TESS-p50-5cm'].ev(fGHz,theta,compensate=False)
sl['TESS-p50-10cm'].ev(fGHz,theta,compensate=False)
sl['TESS-p50-15cm'].ev(fGHz,theta,compensate=False)
    
fig,ax = sl['TESS-p50-5cm'].plotwrt('f',coeff='T',types=['ru'],labels=[''],color='k')
fig,ax = sl['TESS-p50-10cm'].plotwrt('f',coeff='T',types=['ru'],labels=[''],color='k',linestyle='dashed',fig=fig,ax=ax)
fig,ax = sl['TESS-p50-15cm'].plotwrt('f',coeff='T',types=['ru'],labels=[''],color='k',linestyle='dashdot',fig=fig,ax=ax)

# %%
sl['TESS-p50-5cm'].ev(fGHz,theta,compensate=True)
sl['TESS-p50-10cm'].ev(fGHz,theta,compensate=True)
sl['TESS-p50-15cm'].ev(fGHz,theta,compensate=True)

fig,ax = sl['TESS-p50-5cm'].plotwrt('f',coeff='T',types=['ru'],labels=['5cm compensated',''],color='r',fig=fig,ax=ax)
fig,ax = sl['TESS-p50-10cm'].plotwrt('f',coeff='T',types=['ru'],labels=['10cm compensated',''],color='r',linestyle='dashed',fig=fig,ax=ax)
fig,ax = sl['TESS-p50-15cm'].plotwrt('f',coeff='T',types=['ru'],labels=['15cm not compensated',''],color='r',linestyle='dashdot',fig=fig,ax=ax) 

fig,ax = sl['TESS-p50-5cm'].plotwrt('f',coeff='T',labels=[''],color='k')
fig,ax = sl['TESS-p50-10cm'].plotwrt('f',coeff='T',labels=[''],color='k',linestyle='dashed',fig=fig,ax=ax)
fig,ax = sl['TESS-p50-15cm'].plotwrt('f',coeff='T',labels=[''],color='k',linestyle='dashdot',fig=fig,ax=ax)
