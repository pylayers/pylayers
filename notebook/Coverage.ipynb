# %% [markdown]
# # Initialization

# %% [markdown]
# Import the `coverage` module

# %%
from pylayers.antprop.coverage import *
import time

# %% [markdown]
# Instantiate a coverage object.
# By defaut, `TA-Office.str` layout strucure is loaded.
#
# This information can be modified in the **coverage.ini** file in the project directory.

# %% [markdown]
#     [pl_model]
#     sigrss = 3.0
#     f = 3.0
#     rssnp = 2.64
#     d0 = 1.0
#
#
#     [grid]
#     xstep= 40
#     ystep= 20
#
#     [layout]
#     filename = TA-Office.str
#     ;filename = Lstruc.str
#
#     [tx]
#     x = -10
#     y = 10
#     ;transmitted power (dBm)
#     ptdbm = 0
#     ; frame length in bytes
#     framelengthbytes = 50000
#
#     [rx]
#     sensitivity  = -80
#     bandwidthmhz = 3
#     temperaturek = 300
#     noisefactordb = 13
#
#     [show]
#     show = True

# %%
C = Coverage()
C.L.filename
# Out:
# 'DLR.ini'

# %%
C.cover2()

# %% [markdown]
# # Calculating Received Power Coverage

# %% [markdown]
# Coverage required the Layout graphs have been produced.
#
# - If the graphs for the given layout have already been built, they are loaded from the project directory.
# - Otherwise, they are built  **(it may take few minutes depending on the layout complexity)** and stored into the project directory for the next execution.

# %%
try :
    C.L.dumpr()
except:
    C.L.build()

# %% [markdown]
# Then, the coverage calculation can be launched in calling the `cover` method

# %%
C.L.display['nodes']=False
C.L.display['ednodes']=False
C.L.showGs()
# Out:
# (<matplotlib.figure.Figure at 0x51f88d0>,
#  <matplotlib.axes.AxesSubplot at 0x520ac90>)

# %% [markdown]
# The coverage results can be displayed by invoquing various functions.
#
# + showLoss : display the path loss
# + showPower : display the received power

# %%
C.fGHz=0.915
C.cover2()
C.showPower()
# Out:
# (<matplotlib.figure.Figure at 0x511d050>,
#  <matplotlib.axes.AxesSubplot at 0x3333810>)

# %%
C.fGHz=2.4
C.cover2()
C.showPower()
# Out:
# (<matplotlib.figure.Figure at 0x60a8790>,
#  <matplotlib.axes.AxesSubplot at 0x60b0650>)

# %%
C.fGHz=2.4
C.cover2()
C.showPower()
# Out:
# (<matplotlib.figure.Figure at 0x5e12ed0>,
#  <matplotlib.axes.AxesSubplot at 0x60b0110>)

# %% [markdown]
# The transmitter coordinates are :

# %%
C.tx
# Out:
# array([25,  5])

# %% [markdown]
# This can be modified on the flight, and the coverage is updated

# %%
C.tx = np.array((30,12))

# %timeit
C.cover2()

C.showLoss(polarization='o')
C.showPower(polarization='o')
C.showLoss(polarization='p')
C.showPower(polarization='p')
# Out:
# (<matplotlib.figure.Figure at 0x5f85e90>,
#  <matplotlib.axes.AxesSubplot at 0x6628b90>)

# %%
C.tx = np.array((20,1))
start = time.time()
C.cover()
finish = time.time()
print 'All coverage calculated in %1.2f seconds' % (finish-start)
C.showLoss(polarization='o')
C.showPower(polarization='o')
# Out:
# All coverage calculated in 14.36 seconds
# (<matplotlib.figure.Figure at 0x61fd790>,
#  <matplotlib.axes.AxesSubplot at 0x6624610>)

# %%
C.tx = np.array((20,1))
start = time.time()
C.cover2()
finish = time.time()
print 'All coverage calculated in %1.2f seconds' % (finish-start)
C.showLoss(polarization='o')
C.showPower(polarization='o')
# Out:
# All coverage calculated in 0.93 seconds
# (<matplotlib.figure.Figure at 0x5f9e090>,
#  <matplotlib.axes.AxesSubplot at 0x5f79350>)

# %% [markdown]
# The excess delay due to crossing the wall can also be evaluted.

# %%
C.tx = np.array((20,4))
C.cover()
C.showEd()
# Out:
# (<matplotlib.figure.Figure at 0x6996e90>,
#  <matplotlib.axes.AxesSubplot at 0x5f99b10>)

# %%
C.L
# Out:
# ----------------
# DLR.ini
# Image('/home/uguen/Bureau/P1/struc/DLR4991.png')
# ----------------
#
# Number of points  : 105
# Number of segments  : 124
# Number of sub segments  : 30
# Number of cycles  : 20
# Number of rooms  : 16
# degree 0 : []
# degree 1 : []
# degree 2 : 72
# degree 3 : 32
# degree 4 : [-23]
#
# xrange :(-0.505, 32.585999999999999)
# yrange :(-8.2769999999999992, 8.878)
#
# Useful dictionnaries
# ----------------
# di {interaction : [nstr,typi]}
# sl {slab name : slab dictionary}
# name :  {slab :seglist}
#
# Useful arrays
# ----------------
# tsg : get segment index in Gs from tahe
# tgs : get segment index in tahe from Gs
# lsss : list of segments with sub-segment
# sla : associated slab name
# stridess : stride for adressing sub segment
# degree : degree of nodes

# %%
C.L.sl
# Out:
# {'3D_WINDOW_GLASS': fGHz :  [ 2.4]:[ 3.9]:16
# theta : [ 0.95143796]:[ 0.95143796]:1
# | GLASS | AIR | GLASS |
# |-|-|-|
# ,
#  'ABSORBENT': | ABSORBENT |
# |----------|
# ,
#  'AIR': fGHz :  [ 2.4]:[ 3.9]:16
# theta : [ 1.29792871]:[ 1.29792871]:1
# | AIR |
# |--|
# ,
#  'CEIL': | REINFORCED_CONCRETE |
# |----------|
# ,
#  'CONCRETE_15CM3D': | CONCRETE |
# |---------------|
# ,
#  'CONCRETE_20CM3D': | CONCRETE |
# |--------------------|
# ,
#  'CONCRETE_6CM3D': | CONCRETE |
# |------|
# ,
#  'CONCRETE_7CM3D': | CONCRETE |
# |--------|
# ,
#  'DOOR': fGHz :  [ 2.4]:[ 3.9]:16
# theta : [ 1.29567686]:[ 1.29567686]:1
# | WOOD |
# |---|
# ,
#  'FLOOR': | REINFORCED_CONCRETE |
# |----------|
# ,
#  'METAL': | METAL |
# |----------|
# ,
#  'METALIC': | METAL |
# |----------|
# ,
#  'PARTITION': fGHz :  [ 2.4]:[ 3.9]:16
# theta : [ 1.20147159]:[ 1.20147159]:1
# | PLASTER |
# |----------|
# ,
#  'PILLAR': | REINFORCED_CONCRETE |
# |------------------------------|
# ,
#  'PLASTERBOARD_10CM': | PLASTER |
# |----------|
# ,
#  'PLASTERBOARD_14CM': | PLASTER |
# |---------------|
# ,
#  'PLASTERBOARD_7CM': | PLASTER |
# |--------|
# ,
#  'WALL': fGHz :  [ 2.4]:[ 3.9]:16
# theta : [ 0.35728828]:[ 0.35728828]:1
# | BRICK |
# |--------|
# ,
#  'WALLS': | BRICK |
# |---------------|
# ,
#  'WINDOW': | GLASS | AIR | GLASS |
# |-|-|-|
# ,
#  'WINDOW_GLASS': | GLASS |
# |-|
# ,
#  'WOOD': | WOOD |
# |----|
# }

# %%
C.L.sl['DOOR']
# Out:
# fGHz :  [ 2.4]:[ 3.9]:16
# theta : [ 1.29567686]:[ 1.29567686]:1
# | WOOD |
# |---|

# %%
C.L.sl.mat
# Out:
# {'ABSORBENT': {'epr': (1+0j),
#   'index': 0,
#   'mur': (1+0j),
#   'name': 'ABSORBENT',
#   'roughness': 0.0,
#   'sigma': 0.0},
#  'AIR': {'epr': (1+0j),
#   'index': 1,
#   'mur': (1+0j),
#   'name': 'AIR',
#   'roughness': 0.0,
#   'sigma': 0.0},
#  'BRICK': {'epr': (4.09999990463+0j),
#   'index': 2,
#   'mur': (1+0j),
#   'name': 'BRICK',
#   'roughness': 0.0,
#   'sigma': 0.300000011921},
#  'CONCRETE': {'epr': (5.5+0j),
#   'index': 5,
#   'mur': (1+0j),
#   'name': 'CONCRETE',
#   'roughness': 0.0,
#   'sigma': 0.048699988079},
#  'GLASS': {'epr': (3.79999995232+0j),
#   'index': 4,
#   'mur': (1+0j),
#   'name': 'GLASS',
#   'roughness': 0.0,
#   'sigma': 0.0},
#  'METAL': {'epr': (-1-1j),
#   'index': -1,
#   'mur': (1+1j),
#   'name': 'METAL',
#   'roughness': 0.0,
#   'sigma': 1000.0},
#  'PLASTER': {'epr': (8+0j),
#   'index': 3,
#   'mur': (1+0j),
#   'name': 'PLASTER',
#   'roughness': 0.0,
#   'sigma': 0.038},
#  'PLATRE-57GHz': {'epr': (3.097-0.04928j),
#   'index': 10,
#   'mur': (1+0j),
#   'name': 'PLATRE-57GHz',
#   'roughness': 0.0,
#   'sigma': 0.0},
#  'REINFORCED_CONCRETE': {'epr': (8.69999980927+0j),
#   'index': 6,
#   'mur': (1+0j),
#   'name': 'REINFORCED_CONCRETE',
#   'roughness': 0.0,
#   'sigma': 3.0},
#  'SEA_WATER': {'epr': (81+0j),
#   'index': 9,
#   'mur': (1+0j),
#   'name': 'SEA_WATER',
#   'roughness': 0.0,
#   'sigma': 4.0},
#  'STONE': {'epr': (8.69999980927+0j),
#   'index': 8,
#   'mur': (1+0j),
#   'name': 'STONE',
#   'roughness': 0.0,
#   'sigma': 3.0},
#  'WOOD': {'epr': (2.83999991417-0.019999999553j),
#   'index': 7,
#   'mur': (1+0j),
#   'name': 'WOOD',
#   'roughness': 0.0,
#   'sigma': 0.0}}
