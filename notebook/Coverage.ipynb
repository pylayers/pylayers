# %% [markdown]
# # Initialization

# %% [markdown]
# Import the `coverage` module

# %%
from pylayers.antprop.coverage import *
import time

# %% [markdown]
# Instantiate a coverage object.
# By defaut, `TA-Office.str` layout strucure is loaded.
#
# This information can be modified in the **coverage.ini** file in the project directory.
#
# Below is an example of how the content of the file looks like

# %% [markdown]
#     [pl_model]
#     sigrss = 3.0
#     f = 3.0
#     rssnp = 2.64
#     d0 = 1.0
#
#
#     [grid]
#     xstep= 40
#     ystep= 20
#
#     [layout]
#     ;filename = TA-Office.ini
#     ;filename = Lstruc.ini
#     filenbame = DLR.ini
#
#     [tx]
#     x = -10
#     y = 10
#     ;transmitted power (dBm)
#     ptdbm = 0
#     ; frame length in bytes
#     framelengthbytes = 50000
#
#     [rx]
#     sensitivity  = -80
#     bandwidthmhz = 3
#     temperaturek = 300
#     noisefactordb = 13
#
#     [show]
#     show = True

# %%
L=Layout('DLR.ini')
# Out:
# problem to construct geomfile

# %%
L.showG('s')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-7baa8152de41> in <module>()
# ----> 1 L.showG('s')
#
# /private/staff/i/bi/mmhedhbi/pylayers/pylayers/gis/layout.pyc in showG(self, graph, **kwargs)
#    4981         d = self.subseg()
#    4982         for ss in d.keys():
# -> 4983             color = cold[self.sl[ss]['color']]
#    4984             for ns in d[ss]:
#    4985                 norm = self.Gs.node[ns[0]]['norm']
#
# KeyError: 'A'

# %%
# Create a Coverage object from coverag.ini file
C = Coverage()
# Out:
# WARNING:root:first decompose run failed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-7cc41afdf723> in <module>()
#       1 # Create a Coverage object from coverag.ini file
# ----> 2 C = Coverage()
#
# /private/staff/i/bi/mmhedhbi/pylayers/pylayers/antprop/coverage.pyc in __init__(self, _fileini)
#      99         except:
#     100             self.L.buildGt()
# --> 101             self.L.dumpw('t')
#     102
#     103         self.creategrid(full=self.mode,boundary=self.boundary)
#
# /private/staff/i/bi/mmhedhbi/pylayers/pylayers/gis/layout.pyc in dumpw(self, graph)
#    3927                     raise NameError('G'+g+' graph cannot be saved, probably because it has not been built')
#    3928         # save dictionnary which maps string interaction to [interactionnode, interaction type]
# -> 3929         write_gpickle(getattr(self,'di'),basename+'/struc/gpickle/di_'+self.filename+'.gpickle')
#    3930         write_gpickle(getattr(self,'dca'),basename+'/struc/gpickle/dca_'+self.filename+'.gpickle')
#    3931
#
# AttributeError: 'Layout' object has no attribute 'di'
# problem to construct geomfile

# %%
# evaluate coverage 
C.cover()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cb6e43f258ee> in <module>()
#       1 # evaluate coverage
# ----> 2 C.cover()
#
# NameError: name 'C' is not defined

# %% [markdown]
# # Calculating Received Power Coverage

# %% [markdown]
# Coverage required the Layout graphs have been produced.
#
# - If the graphs for the given layout have already been built, they are loaded from the project directory.
# - Otherwise, they are built  **(it may take few minutes depending on the layout complexity)** and stored into the project directory for the next execution.

# %%
try :
    C.L.dumpr()
except:
    C.L.build()

# %% [markdown]
# Then, the coverage calculation can be launched in calling the `cover` method

# %%
C.L.display['nodes']=False
C.L.display['ednodes']=False
C.L.showGs()
# Out:
# (<matplotlib.figure.Figure at 0x48c8fd0>,
#  <matplotlib.axes.AxesSubplot at 0x46c7cd0>)

# %% [markdown]
# The shadowing map coverage results can be displayed by invoquing various functions.
#
# + showLoss : display the path loss
# + showPower : display the received power

# %%
C.fGHz=0.915
C.cover()
C.showPower()
# Out:
# (<matplotlib.figure.Figure at 0x7f31092c6510>,
#  <matplotlib.axes.AxesSubplot at 0x7f30f043f1d0>)

# %%
C.fGHz=2.4
C.cover()
C.showPower()
# Out:
# (<matplotlib.figure.Figure at 0x7f31092c6610>,
#  <matplotlib.axes.AxesSubplot at 0x7f31092cb290>)

# %%
C.fGHz=0.1
C.cover()
C.showPower()
# Out:
# (<matplotlib.figure.Figure at 0x7f310a0ae2d0>,
#  <matplotlib.axes.AxesSubplot at 0x7f3108b6a990>)

# %% [markdown]
# The transmitter coordinates are :

# %%
C.tx
# Out:
# array([25,  5])

# %% [markdown]
# This can be modified on the flight, and the coverage is updated

# %%
C.tx = np.array((21,2))

# %timeit
C.cover()

C.showLoss(polarization='o')
C.showPower(polarization='o')
C.showLoss(polarization='p')
C.showPower(polarization='p')
# Out:
# (<matplotlib.figure.Figure at 0x7f310af11f50>,
#  <matplotlib.axes.AxesSubplot at 0x7f310aef2f10>)

# %% [markdown]
# The excess delay due to crossing the wall can also be evaluted.
