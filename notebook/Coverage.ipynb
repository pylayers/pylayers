# %% [markdown]
# # Initialization

# %% [markdown]
# Import the `coverage` module

# %%
from pylayers.antprop.coverage import *
import time

# %% [markdown]
# Instantiate a coverage object.
# By defaut, `TA-Office.str` layout strucure is loaded.
#
# This information can be modified in the **coverage.ini** file in the project directory.

# %% [markdown]
#     [pl_model]
#     sigrss = 3.0
#     f = 3.0
#     rssnp = 2.64
#     d0 = 1.0
#
#
#     [grid]
#     xstep= 40
#     ystep= 20
#
#     [layout]
#     filename = TA-Office.str
#     ;filename = Lstruc.str
#
#     [tx]
#     x = -10
#     y = 10
#     ;transmitted power (dBm)
#     ptdbm = 0
#     ; frame length in bytes
#     framelengthbytes = 50000
#
#     [rx]
#     sensitivity  = -80
#     bandwidthmhz = 3
#     temperaturek = 300
#     noisefactordb = 13
#
#     [show]
#     show = True

# %%
C = Coverage()
C.L.filename
# Out:
# 'DLR.ini'

# %%
C.cover()
C
# Out:
# tx : [25  5]
# fghz : 3.0
# nx : 80
# ny : 40
# mode : True
# boundary (xmin,ymin,xmax,ymax) : [20, 0, 30, 20]
# rxsens : -80
# bandwithmhz : 3
# temperaturek : 300
# noisefactordb : 13
# plm : {'fghz': '3.0', 'rssnp': '2.64', 'd0': '1.0', 'sigrss': '3.0'}

# %% [markdown]
# # Calculating Received Power Coverage

# %% [markdown]
# Coverage required the Layout graphs have been produced.
#
# - If the graphs for the given layout have already been built, they are loaded from the project directory.
# - Otherwise, they are built  **(it may take few minutes depending on the layout complexity)** and stored into the project directory for the next execution.

# %%
try :
    C.L.dumpr()
except:
    C.L.build()

# %% [markdown]
# Then, the coverage calculation can be launched in calling the `cover` method

# %%
C.L.display['nodes']=False
C.L.display['ednodes']=False
C.L.showGs()
# Out:
# (<matplotlib.figure.Figure at 0x37adfd0>,
#  <matplotlib.axes.AxesSubplot at 0x5e3d750>)

# %% [markdown]
# The coverage results can be displayed by invoquing various functions.
#
# + showLoss : display the path loss
# + showPower : display the received power

# %%
C.fGHz=0.915
C.cover()
C.showPower()
# Out:
# (<matplotlib.figure.Figure at 0x1f2f4d0>,
#  <matplotlib.axes.AxesSubplot at 0x5d98850>)

# %%
C.fGHz=2.4
C.cover()
C.showPower()
# Out:
# (<matplotlib.figure.Figure at 0x4a29a50>,
#  <matplotlib.axes.AxesSubplot at 0x7fdc3c0db290>)

# %% [markdown]
# The transmitter coordinates are :

# %%
C.tx
# Out:
# array([20,  4])

# %% [markdown]
# This can be modified on the flight, and the coverage is updated

# %%
C.tx = np.array((30,12))

# %timeit
C.cover()

C.showLoss(polarization='o')
C.showPower(polarization='o')
C.showLoss(polarization='p')
C.showPower(polarization='p')
# Out:
# (<matplotlib.figure.Figure at 0x7ff89c97aa10>,
#  <matplotlib.axes.AxesSubplot at 0x6456910>)

# %%
C.tx = np.array((39,1))
start = time.time()
C.cover()
finish = time.time()
print 'All coverage calculated in %1.2f seconds' % (finish-start)
C.showLoss(polarization='o')
C.showPower(polarization='o')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-6df775881042> in <module>()
#       1 C.tx = np.array((39,1))
#       2 start = time.time()
# ----> 3 C.cover()
#       4 finish = time.time()
#       5 print 'All coverage calculated in %1.2f seconds' % (finish-start)
#
# /home/uguen/Documents/rch/devel/pylayersbug/pylayers/antprop/coverage.pyc in cover(self)
#     161         """
#     162         #self.Lwo,self.Lwp,self.Edo,self.Edp = Loss0_v2(self.L,self.grid,self.model.f,self.tx)
# --> 163         self.Lwo,self.Lwp,self.Edo,self.Edp = Loss0_v2(self.L,self.grid,self.fGHz,self.tx)
#     164         #self.freespace = PL(self.grid,self.model.f,self.tx)
#     165         self.freespace = PL(self.grid,self.fGHz,self.tx)
#
# /home/uguen/Documents/rch/devel/pylayersbug/pylayers/antprop/multiwall.pyc in Loss0_v2(L, Pts, fGHz, p)
#     251                 #
#     252                 lko,lkp  = L.sl[name].losst(fGHz,the)
# --> 253                 do , dp  = L.sl[name].excess_grdelay(theta=the)
#     254                 edo = edo - np.mean(do)
#     255                 edp = edp - np.mean(dp)
#
# /home/uguen/Documents/rch/devel/pylayersbug/pylayers/antprop/slab.pyc in excess_grdelay(self, fGHz, theta)
#    1414         """
#    1415         df = fGHz[1]-fGHz[0]
# -> 1416         self.ev(fGHz,theta=np.array([theta]),compensate=True)
#    1417         T   = self.T
#    1418         To  = T[:,0,0,0]
#
# /home/uguen/Documents/rch/devel/pylayersbug/pylayers/antprop/slab.pyc in ev(self, fGHz, theta, compensate, RT)
#    1365                                     fGHz[:,np.newaxis,np.newaxis,np.newaxis]
#    1366                                     *d[:,:,np.newaxis,np.newaxis]
# -> 1367                                     /0.3)
#    1368 #        if 'T' in RT:
#    1369 #            epr = [m['epr'] for m in self['lmat']]
#
# IndexError: too many indices

# %% [markdown]
# The excess delay due to crossing the wall can also be evaluted.

# %%
C.tx = np.array((20,4))
C.cover()
C.showEd()
