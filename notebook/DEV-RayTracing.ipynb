# %% [markdown]
# # Simulation Creation

# %%
from pylayers.simul.simulem import *
from pylayers.antprop.rays import *
from pylayers.antprop.channel import *
from pylayers.antprop.signature import *
from pylayers.measures.mesuwb import *
#import pylayers.signal.bsignal as bs
# Out:
# /usr/local/lib/python2.7/dist-packages/mpl_toolkits/__init__.py:2: UserWarning: Module dateutil was already imported from /usr/local/lib/python2.7/dist-packages/dateutil/__init__.pyc, but /usr/lib/pymodules/python2.7 is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)

# %% [markdown]
# Create the simulation object with `WHERE1.ini` layout. This layout corresponds to the office building where the first WHERE1 UWB measurement camapign has been conducted.

# %%
S = Simul()
# loading a layout 
filestr = 'WHERE1_clean'
S.layout(filestr+'.ini','matDB.ini','slabDB.ini')
try:
    S.L.dumpr()
except:
    S.L.build()
    S.L.dumpw()

# %% [markdown]
# The layout display is fully parameterized via the embedded **display** dictionnary member of the Layout object.

# %%
figsize(10,10)    
S.L.display['ednodes']=False
S.L.display['nodes']=False
S.L.display['title']='WHERE1 measurement site'
S.L.display['overlay']=False
S.L.showGs()
# Out:
# (<matplotlib.figure.Figure at 0x5d90410>,
#  <matplotlib.axes.AxesSubplot at 0x5d90a50>)

# %% [markdown]
# ## Adding the coordinates of transmiting and receiving points

# %%
S.tx = RadioNode(_fileini='w2m1tx.ini',_fileant='defant.vsh3')
S.rx = RadioNode(_fileini='w2m1rx.ini',_fileant='defant.vsh3')

# %% [markdown]
# The whole simulation setup can then be displayed using the show method of the Simulation object

# %%
S.show()
# Out:
# Warning : no furniture file loaded
# (<matplotlib.figure.Figure at 0x42d2a10>,
#  <matplotlib.axes.AxesSubplot at 0x42c6490>)

# %% [markdown]
# Select Tx and Rx positions

# %%
dico={1: 1,2: 2, 3: 3, 4: 5, 5: 6, 6: 7, 7: 8, 8: 9, 9: 10,
10: 11, 11: 12, 12: 13, 13: 14, 14: 15, 15: 16, 16: 17, 17: 18, 18: 19, 19: 20,
20: 21, 21: 22, 22: 23, 23: 24, 24: 25, 25: 26, 26: 27,
27: 28, 28: 29, 29: 30, 30: 32, 31: 33, 32: 34, 33: 35, 34: 36, 35: 37, 36: 38,
      37: 39, 38: 40, 39: 41, 40: 42, 41: 43, 42: 44, 43: 45, 44: 46, 45: 47,
      46: 48, 47: 49, 48: 50, 49: 51, 50: 52, 51: 53, 52: 54, 53: 55, 54: 56,
      55: 57, 56: 58, 57: 59, 58: 60, 59: 61, 60: 62, 61: 63, 62: 64, 63: 65,
      64: 66, 65: 67, 66: 68, 67: 69, 68: 70, 69: 71, 70: 72, 71: 73, 72: 74,
      73: 75, 74: 76, 75: 77, 76: 78, 77: 79, 78: 80, 79: 81, 80: 82, 81: 83,
      82: 84, 83: 85, 84: 89, 85: 90, 86: 91, 87: 92, 88: 93, 89: 94, 90: 95,
      91: 96, 92: 97, 93: 98, 94: 99, 95: 100, 96: 101, 97: 103, 98: 104, 99:
      105, 100: 106, 101: 107, 102: 108, 103: 109, 104: 110, 105: 111, 106:
      113, 107: 114, 108: 116, 109: 117, 110: 119, 111: 120, 112: 122, 113:
      123, 114: 124, 115: 125, 116: 126, 117: 127, 118: 128, 119: 129, 120:
      133, 121: 134, 122: 136, 123: 137, 124: 138, 125: 139, 126: 140, 127:
# Tx_height : [u'120cm']
# Tx_position : [u'P179']
# Tx :  [-10.363   10.9376   1.2   ]
# ------Tx1 ------
# delays     (ns): 12.3480199579
# range  (meters): 3.70440598736
# visibility     : NLOS2
# angular (degree)  : 1.02927498532
# LQI Meth1 15.167892203  (dB)
# LQI Meth2 5.88679305325  (dB)
# ------Tx2 ------
# delays     (ns): 31.4002280689
# range  (meters): 9.42006842067
# visibility     : LOS
# angular (degree)  : 5.81625720026
# LQI Meth1 36.1723825836  (dB)
# LQI Meth2 8.98320349882  (dB)
# ------Tx3 ------
# delays     (ns): 21.86283115
# range  (meters): 6.558849345
# visibility     : LOS
# angular (degree)  : 2.81932621034
# LQI Meth1 34.8513231124  (dB)
# LQI Meth2 7.78494547476  (dB)
# ------Tx4 ------
# delays     (ns): 14.7945267104
# range  (meters): 4.43835801311
# visibility     : NLOS
# angular (degree)  : 4.42181483441
# LQI Meth1 22.1369571093  (dB)
# LQI Meth2 4.8320325977  (dB)

# %%
tx= S.tx.points[1]
rx= S.rx.points[150]
M = UWBMesure(dico[150])
rxm = M.tx
txm = M.rx[1]
print tx
print rx
print txm
print rxm
v = tx-rx
d = sqrt(dot(v,v))
print d
print d/0.3
# Out:
# [-12.2724   7.7632   1.2   ]
# [-10.363   10.9376   1.2   ]
# [-12.2724   7.7632   1.2   ]
# [-10.363   10.9376   1.2   ]
# 3.70440598736
# 12.3480199579

# %%
S.L.showGs()
plot(rxm[0],rxm[1],'or')
#ax1.plot(M.rx[1][0],M.rx[1][1],'ob')
plot(txm[0],txm[1],'ob')
plt.show()

# %%
fig=plt.figure(figsize=(10,10))
S.L.showG('t',fig=fig)
# Out:
# (<matplotlib.figure.Figure at 0x6318090>,
#  <matplotlib.axes.AxesSubplot at 0x6318150>)

# %%
Si = Signatures(S.L,25,25)
Si.run1(cutoff=6)
#Si.keys()

# %%
r2d = Si.rays(tx,rx)

# %%
#r2d.show3(strucname='WHERE1')

# %%
#r2d.keys()

# %%
r3d=r2d.to3D()

# %%
#r3d.show3(strucname='WHERE1')

# %%
r3d.locbas(S.L)

# %%
r3d.fillinter(S.L)

# %%
#r3d

# %%
#S.freq

# %%
Ct = r3d.eval(S.freq)
# Out:
# Rays evaluation

# %%
#r3d.keys()
#r3d.typ(3)

# %%
Ct.freq = S.freq

# %%
sco=Ct.prop2tran(a='theta',b='theta')
sca= Ct.prop2tran(a=S.tx.A,b=S.rx.A)

# %%
#Ct.show()

# %%
wav = wvf.Waveform({'type':'file'})
#wav = wvf.Waveform({'type' : 'generic','band': 0.499,'fc': 4.493, 'fe': 100, 'thresh': 3, 'tw': 30})
#wav.show()

# %%
ciro = sco.applywavB(wav.sfg)
cira = sca.applywavB(wav.sfg)

# %%
ciro.plot()

# %%
cira.plot()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(311,title="Measurements")
M.tdd.ch3.plot()
# align for plotting
cira.x=cira.x-cira.x[0]
#ciro.x=ciro.x-ciro.x[0]
ax2 = fig.add_subplot(312,title="Simulation-with antenna",sharex=ax1, sharey=ax1)
cira.plot()
#ax3 = fig.add_subplot(313,title="Simulation-without antenna",sharex=ax1, sharey=ax1)
#ciro.plot()
